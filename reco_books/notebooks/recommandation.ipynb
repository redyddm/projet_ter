# %% [markdown]
# # Système de recommandation de livres basé sur le contenu

# %% [markdown]
# ## Imports et chargement des données

# %%
import pandas as pd
import numpy as np
import os
import json
import psycopg2
import re
import ast
import nltk
import gensim
import glob
import joblib
import torch
import pickle
import unicodedata

from tqdm import tqdm
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import normalize

from scipy import sparse
from gensim.parsing.preprocessing import remove_stopwords

from sentence_transformers import SentenceTransformer

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from surprise import SVD, NMF, Dataset, Reader, BaselineOnly, AlgoBase , SVDpp,  dump, accuracy
from surprise.model_selection import train_test_split
from surprise.model_selection import GridSearchCV
from surprise.model_selection.search import RandomizedSearchCV


# les imports qui suivent sont d'un dossier package créé pour éviter de faire toutes les opérations dans le notebook


# utils : contient les fonctions globales
# reco_collab_initial contient les fonctions pour la recommandation collaborative sur ce dataset précis

# %load_ext autoreload
# %autoreload 2

from package.utils import *
from package.reco_collab_initial import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = "../data/raw/Recommender_dataset/"

books = pd.read_csv(path+"Books.csv")
users= pd.read_csv(path+"Users.csv")
ratings = pd.read_csv(path+"Ratings.csv")

# %%
def save_df_to_csv(df, path):
    """ Crée un fichier csv à partir d'un dataframe.
        Arguments :
            df (DataFrame)
            path (str) : chemin du fichier qui sera créé.
    """
    df.to_csv(path, index=False, header=True)

def save_df_to_pickle(df, path):
    """ Crée un fichier pkl à partir d'un dataframe. C'est pour garder le type list des sujets et descriptions.
        Arguments :
            df (DataFrame)
            path (str) : chemin du fichier qui sera créé.
    """
    df.to_pickle(path)

# %%
import ast
import re

def str_list_to_text(s):
    if isinstance(s, str):
        return s
    else :
        parsed = ast.literal_eval(s)
        return " ".join(parsed)

def enlever_parentheses(texte):
    resultat = []
    niveau_parenthese = 0

    for char in texte:
        if char == '(':
            niveau_parenthese += 1
        elif char == ')':
            if niveau_parenthese > 0:
                niveau_parenthese -= 1
        else:
            if niveau_parenthese == 0:
                resultat.append(char)

    return ''.join(resultat).strip()

# %%
import ast
import json

def str_to_list_auto(val):
    if isinstance(val, list):
        return val  # déjà une liste
    if val is None or val == '':
        return []
    try:
        # Essaye JSON (["a", "b"])
        return json.loads(val)
    except (json.JSONDecodeError, TypeError):
        try:
            # Essaye une liste Python ("['a', 'b']")
            return ast.literal_eval(val)
        except (ValueError, SyntaxError):
            # Sinon, split sur virgule simple
            return [x.strip() for x in val.split(',') if x.strip()]

# %%
import re

def remove_parentheses(text):
    print(re.sub(r'\s*\(.*?\)', '', text).strip())
    return re.sub(r'\s*\(.*?\)', '', text).strip()

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
ratings.columns
# Out:
# Index(['User-ID', 'ISBN', 'Book-Rating'], dtype='object')

# %%
users.columns
# Out:
# Index(['User-ID', 'Location', 'Age'], dtype='object')

# %%
books.rename(columns={'Book-Title':'title', 'Book-Author': 'author','Year-Of-Publication':'year', 'Publisher':'publisher'}, inplace=True)
books.drop(columns=['Image-URL-S', 'Image-URL-M', 'Image-URL-L'], inplace=True)
books.head(10)
# Out:
#          ISBN                                              title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
# 5  0399135782                             The Kitchen God's Wife
# 6  0425176428  What If?: The World's Foremost Military Histor...
# 7  0671870432                                    PLEADING GUILTY
# 8  0679425608  Under the Black Flag: The Romance and the Real...
# 9  074322678X            Where You'll Find Me: And Other Stories
#
#                  author  year                   publisher
# 0    Mark P. O. Morford  2002     Oxford University Press
# 1  Richard Bruce Wright  2001       HarperFlamingo Canada
# 2          Carlo D'Este  1991             HarperPerennial
# 3      Gina Bari Kolata  1999        Farrar Straus Giroux
# 4       E. J. W. Barber  1999  W. W. Norton &amp; Company
# 5               Amy Tan  1991            Putnam Pub Group
# 6         Robert Cowley  2000    Berkley Publishing Group
# 7           Scott Turow  1993                  Audioworks
# 8       David Cordingly  1996                Random House
# 9           Ann Beattie  2002                    Scribner

# %%
ratings.rename(columns={'User-ID':'user_id', 'Book-Rating':'rating'}, inplace=True)
ratings.head(10)
# Out:
#    user_id        ISBN  rating
# 0   276725  034545104X       0
# 1   276726  0155061224       5
# 2   276727  0446520802       0
# 3   276729  052165615X       3
# 4   276729  0521795028       6
# 5   276733  2080674722       0
# 6   276736  3257224281       8
# 7   276737  0600570967       6
# 8   276744  038550120X       7
# 9   276745   342310538      10

# %%
users.rename(columns={'User-ID':'user_id', 'Location':'location','Age':'age'}, inplace=True)
users.head(10)
# Out:
#    user_id                            location   age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN
# 5        6       santa monica, california, usa  61.0
# 6        7                 washington, dc, usa   NaN
# 7        8            timmins, ontario, canada   NaN
# 8        9          germantown, tennessee, usa   NaN
# 9       10          albacete, wisconsin, spain  26.0

# %%
def show_image(url, width=100):
    """ Affiche les images du dataset"""
    return f'<img src="{url}" width="{width}">'

def url_to_img(df, func):
    return df.style.format({'Image-URL-S':func, 'Image-URL-M':func, 'Image-URL-L':func}, escape=False)

# %% [markdown]
# ## Préparation des données

# %%
books.isnull().sum()
# Out:
# ISBN         0
# title        0
# author       2
# year         0
# publisher    2
# dtype: int64

# %%
books.dropna(inplace=True)
books.isnull().sum()
# Out:
# ISBN         0
# title        0
# author       0
# year         0
# publisher    0
# dtype: int64

# %%
books.shape
# Out:
# (271356, 5)

# %%
books.duplicated().sum()
# Out:
# 0

# %%
ratings.isnull().sum()
# Out:
# user_id    0
# ISBN       0
# rating     0
# dtype: int64

# %%
ratings.duplicated().sum()
# Out:
# 0

# %%
ratings['user_id'].value_counts()
# Out:
# user_id
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 116180        1
# 116166        1
# 116154        1
# 116137        1
# 276723        1
# Name: count, Length: 105283, dtype: int64

# %%
users.isnull().sum()
# Out:
# user_id          0
# location         0
# age         110762
# dtype: int64

# %%
users.shape
# Out:
# (278858, 3)

# %% [markdown]
# ## Feature engineering
#
# - Ajout des genres et descritpion (si possible) des livres dans le dataset
# - Ajout de la note moyenne de chaque livre
# - Ajout de la note moyenne de l'utilisateur
# - Ajout du nombre de notes de chaque livre
# - Fusion des datasets pour en avoir un basé sur les utilisateurs avec leurs notes moyennes et celles des livres

# %% [markdown]
# ### API openlibrary (tests)

# %%
import pandas as pd
import requests
import time

# Utiliser les 10 premiers ISBNs pour test
isbns = books['ISBN'].dropna().unique()

# Stocker les genres extraits
extracted_genres = []

for isbn in isbns:
    try:
        url = f"https://openlibrary.org/api/books?bibkeys=ISBN:{isbn}&jscmd=details&format=json"
        response = requests.get(url)
        data = response.json()

        key = f"ISBN:{isbn}"
        genres = data.get(key, {}).get('details', {}).get('subjects', [])
        
        # Extraire les noms des genres
        genres_list = [g['name'] if isinstance(g, dict) else g for g in genres]

        extracted_genres.append({
            'ISBN': isbn,
            'genres_from_api': ', '.join(genres_list)
        })

        # Pause pour éviter d’être bloqué par l’API
        time.sleep(1)

    except Exception as e:
        extracted_genres.append({'ISBN': isbn, 'genres_from_api': None})
        print(f"Erreur avec ISBN {isbn} : {e}")

# Convertir en DataFrame et enregistrer
genres_df = pd.DataFrame(extracted_genres)
genres_df.to_csv("genres_from_openlibrary.csv", index=False)

print("✅ Extraction terminée !")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 2
#       1 import pandas as pd
# ----> 2 import requests
#       3 import time
#       5 # Utiliser les 10 premiers ISBNs pour test
#
# ModuleNotFoundError: No module named 'requests'

# %% [markdown]
# ### Ajout des genres et description en utilisant les dumps d'openlibrary

# %% [markdown]
# Avant de faire ça, j'ai créé une base de données avec postgresql grâce à : https://github.com/LibrariesHacked/openlibrary-search

# %%
def get_key_books(isbn_list):
    """ Permet de récupérer une liste de key de la table 'editions' pour chaque isbn de la liste. 
        (C'est une liste de listes de key).
        Arguments :
            isbn_list (str[]) : liste d'isbn
    """
    conn = psycopg2.connect(
        dbname='openlibrary',
        user='user',
        password='password',
        host='localhost',
        port='5432'
    )
    conn.autocommit = True
    cur = conn.cursor()

    sql = """
        SELECT e.key
        FROM editions e
        JOIN edition_isbns ei ON ei.edition_key = e.key
        WHERE ei.isbn = %s
    """

    key_books = []
    for isbn in tqdm(isbn_list):
        cur.execute(sql, (isbn,))
        results = cur.fetchall()
        key_books.append(results)

    cur.close()
    conn.close()

    return key_books

# %%
def get_key_books_list(isbn_list):
    """ Renvoie une liste de key de la table 'editions' correspondant aux isbn donnés.
        Arguments :
            isbn_list (str[]) : liste d'isbn
    """
    conn = psycopg2.connect(
        dbname='openlibrary',
        user='user',
        password='password',
        host='localhost',
        port='5432'
    )
    conn.autocommit = True
    cur = conn.cursor()

    sql = """
        SELECT e.key
        FROM editions e
        JOIN edition_isbns ei ON ei.edition_key = e.key
        WHERE ei.isbn = %s
    """

    key_books = []
    for isbn in tqdm(isbn_list):
        cur.execute(sql, (isbn,))
        results = cur.fetchall()
        key_books.extend([r[0] for r in results])

    cur.close()
    conn.close()

    return key_books

# %%
isbn_list=books['ISBN']
isbn_list
# Out:
# 0         0195153448
# 1         0002005018
# 2         0060973129
# 3         0374157065
# 4         0393045218
#              ...
# 271355    0440400988
# 271356    0525447644
# 271357    006008667X
# 271358    0192126040
# 271359    0767409752
# Name: ISBN, Length: 271356, dtype: object

# %%
keys=get_key_books_list(isbn_list)
# Out:
# 100%|██████████| 271356/271356 [04:17<00:00, 1054.76it/s]

# %%
keys_books=get_key_books(isbn_list)
# Out:
# 100%|██████████| 271356/271356 [03:54<00:00, 1157.51it/s]

# %%
keys[:10]
# Out:
# ['/books/OL18389036M',
#  '/books/OL22232624M',
#  '/books/OL7390154M',
#  '/books/OL3597106M',
#  '/books/OL22133369M',
#  '/books/OL1890897M',
#  '/books/OL20945359M',
#  '/books/OL7423081M',
#  '/books/OL23243677M',
#  '/books/OL358977M']

# %%
keys_books[:10]
# Out:
# [[('/books/OL18389036M',), ('/books/OL22232624M',), ('/books/OL7390154M',)],
#  [('/books/OL3597106M',), ('/books/OL22133369M',)],
#  [('/books/OL1890897M',), ('/books/OL20945359M',)],
#  [('/books/OL7423081M',), ('/books/OL23243677M',)],
#  [('/books/OL358977M',)],
#  [('/books/OL1530439M',)],
#  [('/books/OL7504546M',), ('/books/OL24223668M',)],
#  [('/books/OL27242140M',)],
#  [('/books/OL804879M',)],
#  [('/books/OL3659400M',)]]

# %%
books_with_keys=pd.DataFrame({
    'ISBN': isbn_list,
    'key_book': keys_books
}, columns=['ISBN', 'key_book'])

# %%
# Sauvegarde du dataframe pour ne plus faire l'opération

save_df_to_csv(books_with_keys, '../../datasets/isbn_with_OLkey.csv')

# %% [markdown]
# La base a été créée. On cherche maintenant à relier les editions à un work correspondant. Les editions peuvent avoir dans leur champ data (fichier json) une colonne work qui contient une clé key de la table works. Comme le nombre d'edition est massif, un index a d'abord été fait sur edition_isbns (table reliant les editions à leur isbn) pour accélérer le temps des requêtes. Ensuite grâce à la fonction get_key_books_list au-dessus, on récupère uniquement les clés des livres de notre dataset initial. La fonction update_editions_work_key ci-dessous permet de faire la liaison entre l'edition et le work uniquement aux livres concernés.

# %%
def update_editions_work_key(keys_list):
    conn = psycopg2.connect(
        dbname='openlibrary',
        user='user',
        password='password',
        host='localhost',
        port='5432'
    )
    conn.autocommit = True
    cur = conn.cursor()

    query = """
        UPDATE editions
        SET work_key = data->'works'->0->>'key'
        WHERE key = %s;
    """

    for key in tqdm(keys_list):
        cur.execute(query, (key,))

    cur.close()
    conn.close()

# %%
update_editions_work_key(keys)
# Out:
# 100%|██████████| 367546/367546 [13:09<00:00, 465.64it/s]

# %% [markdown]
# Maintenant, on peut récupérer les informations que l'on souhaite pour chacun des livres de notre dataset avec la fonction get_infos_by_isbn_list.

# %%
def split_subject_words(subject):
    """ Permet de séparer les mots tout en ignorant la ponctuation et les espaces. 
        On met aussi en minuscule les mots pour éciter la casse.
        Arguments :
            subject (str) : liste de genres retournés lors de la requête sql
    """
    return re.findall(r'\b\w+\b', subject.lower())

def get_infos_by_isbn_list(isbn_list):
    conn = psycopg2.connect(
        dbname='openlibrary',
        user='user', 
        password='password', 
        host='localhost',
        port='5432'
    )
    conn.autocommit = True
    cur = conn.cursor()

    # Requête sql permettant de récupérer les genres et descriptions d'un livre via son isbn
    sql = """
        select
        e.data->>'subjects' "Subjects",
        w.data->'description'->>'value' "WorkDescription"
    from editions e
    join edition_isbns ei
        on ei.edition_key = e.key
    join works w
        on w.key = e.work_key
    where ei.isbn = %s
    """

    # Comme on peut avoir plusieurs résultats pour un même isbn, 
    # la requête renverra plusieurs fois des subjects et descriptions (assez souvent identiques)
    # On traite de ce cas juste après
    
    subjects_final= [] # liste de listes qui contiendra les genres recueillis de chaque livre
    desc_final=[] # liste des descriptions des livres

    for isbn in tqdm(isbn_list):
        cur.execute(sql, (isbn,))
        results = cur.fetchall()

        # On crée ici des sets pour éviter les doublons lors de l'ajout des genres ou descriptions
        all_words = set()
        description_set = set()

        for r in results:
            
            if r[0]:
                subjects_list = json.loads(r[0]) 
                for subject in subjects_list:
                    words = split_subject_words(subject) # On sépare les mots des listes de genres qu'on obtient 
                                                         # pour comparer avec les suivants et ne pas ajouter de doublon
                    for w in words:
                        all_words.add(w)

            
            if r[1]:
                description_set.add(r[1])

        subjects_words = list(all_words)
        descriptions = list(description_set)
        subjects_final.append(subjects_words)
        desc_final.append(descriptions)

    cur.close()
    conn.close()

    return subjects_final, desc_final

# %%
subjects, description=get_infos_by_isbn_list(isbn_list)
# Out:
# 100%|██████████| 271356/271356 [09:23<00:00, 481.44it/s]

# %%
books_desc=pd.DataFrame({
    'ISBN': isbn_list,
    'sujets': subjects,
    'description': description
})

# %%
books_desc
# Out:
#               ISBN                                             sujets  \
# 0       0195153448                             [mythology, classical]
# 1       0002005018  [york, ontario, teachers, sisters, fiction, ac...
# 2       0060973129  [war, 1945, campaigns, world, france, history,...
# 3       0374157065                [century, influenza, 20th, history]
# 4       0393045218  [age, basin, prehistoric, tarim, zizhiqu, mumm...
# ...            ...                                                ...
# 271355  0440400988                         [juvenile, camps, fiction]
# 271356  0525447644                   [juvenile, counting, literature]
# 271357  006008667X  [century, states, american, alternate, history...
# 271358  0192126040  [works, utopias, early, science, 1800, to, pol...
# 271359  0767409752  [god, c, philosophia, 1600, history, ontologic...
#
#                                               description
# 0       [An excellent primer on classical mythology fo...
# 1       [E-book extras: "Hero of the Humdrum": A profi...
# 2                                                      []
# 3       [The fascinating, true story of the world's de...
# 4       [In the museums of Urumchi, the wind-swept reg...
# ...                                                   ...
# 271355  [On her own for the first time, fourteen-year-...
# 271356  [Illustrations of people and animals introduce...
# 271357  [In Lily Dale, New York, the dead don't die. I...
# 271358  [The Republic is Plato's most famous work and ...
# 271359                                                 []
#
# [271356 rows x 3 columns]

# %%
books_desc['sujets']=books_desc['sujets'].apply(str_to_list_auto)
books_desc['description']=books_desc['description'].apply(str_to_list_auto)

# %%
save_df_to_pickle(books_desc, '../../datasets/books_desc.pkl')

# %%
save_df_to_csv(books_desc, '../../datasets/books_desc.csv')

# %%
books_desc=pd.read_pickle('../../datasets/books_desc.pkl')

# %%
books_desc.head()
# Out:
#          ISBN                                             sujets  \
# 0  0195153448                             [mythology, classical]
# 1  0002005018  [york, ontario, teachers, sisters, fiction, ac...
# 2  0060973129  [war, 1945, campaigns, world, france, history,...
# 3  0374157065                [century, influenza, 20th, history]
# 4  0393045218  [age, basin, prehistoric, tarim, zizhiqu, mumm...
#
#                                          description
# 0  [An excellent primer on classical mythology fo...
# 1  [E-book extras: "Hero of the Humdrum": A profi...
# 2                                                 []
# 3  [The fascinating, true story of the world's de...
# 4  [In the museums of Urumchi, the wind-swept reg...

# %% [markdown]
# En voyant les premières lignes du DataFrame, on remarque des listes vides si la description ou les sujets ne sont pas trouvables. On va chercher ceux qui ont au moins une description, pour avoir un maximum de mots pour l'entrainement des modèles en NLP.

# %%
books_desc_non_empty = books_desc[
    books_desc['description'].apply(lambda x: len(x) > 0)
].copy()

# %%
type(books_desc_non_empty.iloc[0]['description'])
# Out:
# list

# %% [markdown]
# Les descriptions sont une liste avec la phrase qui est un str. On veut uniquement le str dans notre colonne et on fait pareil pour les sujets.

# %%
books_desc_non_empty['description'] = books_desc_non_empty['description'].apply(lambda x: " ".join(x) if isinstance(x, list) else str(x))
books_desc_non_empty['sujets'] = books_desc_non_empty['sujets'].apply(lambda x: ", ".join(x) if isinstance(x, list) else str(x))

# %%
books_desc_non_empty.head()
# Out:
#          ISBN                                             sujets  \
# 0  0195153448                               mythology, classical
# 1  0002005018  york, ontario, teachers, sisters, fiction, act...
# 3  0374157065                  century, influenza, 20th, history
# 4  0393045218  age, basin, prehistoric, tarim, zizhiqu, mummi...
# 6  0425176428           imaginary, battles, histories, wars, and
#
#                                          description
# 0  An excellent primer on classical mythology for...
# 1  E-book extras: "Hero of the Humdrum": A profil...
# 3  The fascinating, true story of the world's dea...
# 4  In the museums of Urumchi, the wind-swept regi...
# 6  With its in-depth reflections on the monumenta...

# %%
save_df_to_csv(books_desc_non_empty, '../../datasets/tmp/books_desc_non_empty_only_desc.csv')

# %%
save_df_to_pickle(books_desc_non_empty, '../../datasets/tmp/books_desc_non_empty_only_desc.pkl')

# %%
books_desc_non_empty=pd.read_pickle('../../datasets/tmp/books_desc_non_empty_only_desc.pkl')

# %% [markdown]
# On veut maintenant enlever les stop words des sujets pour n'avoir que les mots intéressants. On fait ça parce que ce sont les thèmes des livres qu'on a gardés.

# %%
books_desc_non_empty['sujets']=books_desc_non_empty['sujets'].apply(remove_stopwords)

# %% [markdown]
# Maintenant que c'est fait, reformons la liste des sujets.

# %%
books_desc_non_empty['sujets']=books_desc_non_empty['sujets'].apply(lambda x : x.split(','))

# %%
books_desc_non_empty.reset_index(drop=True, inplace=True)

# %%
books_desc_non_empty
# Out:
#              ISBN                                             sujets  \
# 0      0195153448                            [mythology,  classical]
# 1      0002005018  [york,  ontario,  teachers,  sisters,  fiction...
# 2      0374157065             [century,  influenza,  20th,  history]
# 3      0393045218  [age,  basin,  prehistoric,  tarim,  zizhiqu, ...
# 4      0425176428         [imaginary,  battles,  histories,  wars, ]
# ...           ...                                                ...
# 79336  014002803X                       [general,  modern,  fiction]
# 79337  0440400988                       [juvenile,  camps,  fiction]
# 79338  0525447644                 [juvenile,  counting,  literature]
# 79339  006008667X  [century,  states,  american,  alternate,  his...
# 79340  0192126040  [works,  utopias,  early,  science,  1800,  to...
#
#                                              description
# 0      An excellent primer on classical mythology for...
# 1      E-book extras: "Hero of the Humdrum": A profil...
# 2      The fascinating, true story of the world's dea...
# 3      In the museums of Urumchi, the wind-swept regi...
# 4      With its in-depth reflections on the monumenta...
# ...                                                  ...
# 79336  Amid preparations for Operation Apollo, secret...
# 79337  On her own for the first time, fourteen-year-o...
# 79338  Illustrations of people and animals introduce ...
# 79339  In Lily Dale, New York, the dead don't die. In...
# 79340  The Republic is Plato's most famous work and o...
#
# [79341 rows x 3 columns]

# %%
save_df_to_csv(books_desc_non_empty, '../../datasets/tmp/books_desc_non_empty_only_desc.csv')

# %%
save_df_to_pickle(books_desc_non_empty, '../../datasets/tmp/books_desc_non_empty_only_desc.pkl')

# %% [markdown]
# Maintenant on fusionne le dernier dataset avec books.

# %%
books_final=books.merge(books_desc_non_empty, on='ISBN')

# %%
books_final
# Out:
#              ISBN                                              title  \
# 0      0195153448                                Classical Mythology
# 1      0002005018                                       Clara Callan
# 2      0374157065  Flu: The Story of the Great Influenza Pandemic...
# 3      0393045218                             The Mummies of Urumchi
# 4      0425176428  What If?: The World's Foremost Military Histor...
# ...           ...                                                ...
# 79336  014002803X                                  Anti Death League
# 79337  0440400988                         There's a Bat in Bunk Five
# 79338  0525447644                            From One to One Hundred
# 79339  006008667X  Lily Dale : The True Story of the Town that Ta...
# 79340  0192126040                        Republic (World's Classics)
#
#                      author  year                        publisher  \
# 0        Mark P. O. Morford  2002          Oxford University Press
# 1      Richard Bruce Wright  2001            HarperFlamingo Canada
# 2          Gina Bari Kolata  1999             Farrar Straus Giroux
# 3           E. J. W. Barber  1999       W. W. Norton &amp; Company
# 4             Robert Cowley  2000         Berkley Publishing Group
# ...                     ...   ...                              ...
# 79336         Kingsley Amis  1975                     Viking Press
# 79337        Paula Danziger  1988  Random House Childrens Pub (Mm)
# 79338            Teri Sloat  1991                     Dutton Books
# 79339      Christine Wicker  2004               HarperSanFrancisco
# 79340                 Plato  1996          Oxford University Press
#
#                                                   sujets  \
# 0                                [mythology,  classical]
# 1      [york,  ontario,  teachers,  sisters,  fiction...
# 2                 [century,  influenza,  20th,  history]
# 3      [age,  basin,  prehistoric,  tarim,  zizhiqu, ...
# 4             [imaginary,  battles,  histories,  wars, ]
# ...                                                  ...
# 79336                       [general,  modern,  fiction]
# 79337                       [juvenile,  camps,  fiction]
# 79338                 [juvenile,  counting,  literature]
# 79339  [century,  states,  american,  alternate,  his...
# 79340  [works,  utopias,  early,  science,  1800,  to...
#
#                                              description
# 0      An excellent primer on classical mythology for...
# 1      E-book extras: "Hero of the Humdrum": A profil...
# 2      The fascinating, true story of the world's dea...
# 3      In the museums of Urumchi, the wind-swept regi...
# 4      With its in-depth reflections on the monumenta...
# ...                                                  ...
# 79336  Amid preparations for Operation Apollo, secret...
# 79337  On her own for the first time, fourteen-year-o...
# 79338  Illustrations of people and animals introduce ...
# 79339  In Lily Dale, New York, the dead don't die. In...
# 79340  The Republic is Plato's most famous work and o...
#
# [79341 rows x 7 columns]

# %% [markdown]
# On a enfin les descriptions avec les livres. On a quand même réduit notre dataset de manière assez conséquente mais on a au moins assez de texte par livre pour pouvoir faire un meilleur entrainement.

# %% [markdown]
# Maintenant, on veut enlever les balises html des textes pour éviter du bruit.

# %%
import html

books_final['description'] = books_final['description'].apply(lambda x: re.sub(r'<.*?>', '', html.unescape(x)))
books_final['title'] = books_final['title'].apply(lambda x: re.sub(r'<.*?>', '', html.unescape(x)))
books_final['author'] = books_final['author'].apply(lambda x: re.sub(r'<.*?>', '', html.unescape(x)))
books_final['publisher'] = books_final['publisher'].apply(lambda x: re.sub(r'<.*?>', '', html.unescape(x)))

# %%
books_final.head()
# Out:
#          ISBN                                              title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 3  0393045218                             The Mummies of Urumchi
# 4  0425176428  What If?: The World's Foremost Military Histor...
#
#                  author  year                 publisher  \
# 0    Mark P. O. Morford  2002   Oxford University Press
# 1  Richard Bruce Wright  2001     HarperFlamingo Canada
# 2      Gina Bari Kolata  1999      Farrar Straus Giroux
# 3       E. J. W. Barber  1999    W. W. Norton & Company
# 4         Robert Cowley  2000  Berkley Publishing Group
#
#                                               sujets  \
# 0                            [mythology,  classical]
# 1  [york,  ontario,  teachers,  sisters,  fiction...
# 2             [century,  influenza,  20th,  history]
# 3  [age,  basin,  prehistoric,  tarim,  zizhiqu, ...
# 4         [imaginary,  battles,  histories,  wars, ]
#
#                                          description
# 0  An excellent primer on classical mythology for...
# 1  E-book extras: "Hero of the Humdrum": A profil...
# 2  The fascinating, true story of the world's dea...
# 3  In the museums of Urumchi, the wind-swept regi...
# 4  With its in-depth reflections on the monumenta...

# %%
save_df_to_csv(books_final, '../../datasets/preprocess/books_final.csv')
save_df_to_pickle(books_final, '../../datasets/preprocess/books_final.pkl')

# %%
books_final=pd.read_pickle('../../datasets/preprocess/books_final.pkl')

# %%
books_final.head()
# Out:
#          ISBN                                              title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 3  0393045218                             The Mummies of Urumchi
# 4  0425176428  What If?: The World's Foremost Military Histor...
#
#                  author  year                 publisher  \
# 0    Mark P. O. Morford  2002   Oxford University Press
# 1  Richard Bruce Wright  2001     HarperFlamingo Canada
# 2      Gina Bari Kolata  1999      Farrar Straus Giroux
# 3       E. J. W. Barber  1999    W. W. Norton & Company
# 4         Robert Cowley  2000  Berkley Publishing Group
#
#                                               sujets  \
# 0                            [mythology,  classical]
# 1  [york,  ontario,  teachers,  sisters,  fiction...
# 2             [century,  influenza,  20th,  history]
# 3  [age,  basin,  prehistoric,  tarim,  zizhiqu, ...
# 4         [imaginary,  battles,  histories,  wars, ]
#
#                                          description
# 0  An excellent primer on classical mythology for...
# 1  E-book extras: "Hero of the Humdrum": A profil...
# 2  The fascinating, true story of the world's dea...
# 3  In the museums of Urumchi, the wind-swept regi...
# 4  With its in-depth reflections on the monumenta...

# %% [markdown]
# ## Création du dataset pour la recommandation basée sur le contenu

# %%
content_df=books_final.copy() #dataset pour la recommandation basée sur le contenu

# %%
content_df.shape
# Out:
# (79341, 7)

# %%
content_df.head()
# Out:
#          ISBN                                              title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 3  0393045218                             The Mummies of Urumchi
# 4  0425176428  What If?: The World's Foremost Military Histor...
#
#                  author  year                 publisher  \
# 0    Mark P. O. Morford  2002   Oxford University Press
# 1  Richard Bruce Wright  2001     HarperFlamingo Canada
# 2      Gina Bari Kolata  1999      Farrar Straus Giroux
# 3       E. J. W. Barber  1999    W. W. Norton & Company
# 4         Robert Cowley  2000  Berkley Publishing Group
#
#                                               sujets  \
# 0                            [mythology,  classical]
# 1  [york,  ontario,  teachers,  sisters,  fiction...
# 2             [century,  influenza,  20th,  history]
# 3  [age,  basin,  prehistoric,  tarim,  zizhiqu, ...
# 4         [imaginary,  battles,  histories,  wars, ]
#
#                                          description
# 0  An excellent primer on classical mythology for...
# 1  E-book extras: "Hero of the Humdrum": A profil...
# 2  The fascinating, true story of the world's dea...
# 3  In the museums of Urumchi, the wind-swept regi...
# 4  With its in-depth reflections on the monumenta...

# %%
save_df_to_pickle(content_df, '../../datasets/reco_datasets/content_dataset.pkl')

# %% [markdown]
# ## Création du dataset pour la recommandation collaborative

# %% [markdown]
# Avant tout ça, on va ajouter une colonne 'is_implicit' pour faciliter les utilisations de modèles collaboratif plus tard. Dans la page kaggle, ils disent que les notes vont de 1 à 10 et que s'il y a un 0, c'est une interaction implicite.

# %%
ratings_explicit=ratings[ratings['rating'] != 0].copy()
ratings_implicit=ratings[ratings['rating'] == 0].copy()

# %%
save_df_to_csv(ratings_implicit, '../../datasets/reco_datasets/ratings_implicit.csv')
save_df_to_pickle(ratings_implicit, '../../datasets/reco_datasets/ratings_implicit.pkl')

# %%
ratings_explicit.head()
# Out:
#    user_id        ISBN  rating
# 1   276726  0155061224       5
# 3   276729  052165615X       3
# 4   276729  0521795028       6
# 6   276736  3257224281       8
# 7   276737  0600570967       6

# %%
ratings_implicit.head()
# Out:
#     user_id        ISBN  rating
# 0    276725  034545104X       0
# 2    276727  0446520802       0
# 5    276733  2080674722       0
# 10   276746  0425115801       0
# 11   276746  0449006522       0

# %%
ratings_explicit.sort_values(by='user_id', inplace=True)
ratings_explicit.reset_index(drop=True, inplace=True)
ratings_explicit.head()
# Out:
#    user_id        ISBN  rating
# 0        8  0002005018       5
# 1        8  1881320189       7
# 2        8  1575663937       6
# 3        8  074322678X       5
# 4        8  1552041778       5

# %%
ratings_implicit.sort_values(by='user_id', inplace=True)
ratings_implicit.reset_index(drop=True, inplace=True)
ratings_implicit.head()
# Out:
#    user_id        ISBN  rating
# 0        2  0195153448       0
# 1        7   034542252       0
# 2        8  0425176428       0
# 3        8  1558746218       0
# 4        8  080652121X       0

# %%
ratings_explicit['user_id'].value_counts()
# Out:
# user_id
# 11676     8524
# 98391     5802
# 153662    1969
# 189835    1906
# 23902     1395
#           ...
# 84129        1
# 165812       1
# 34231        1
# 165826       1
# 41658        1
# Name: count, Length: 77805, dtype: int64

# %% [markdown]
# On voit que certains utilisateurs n'ont intéragi qu'avec un livre alors que d'autres l'ont fait avec beaucoup. On va prendre les utilisateurs qui ont intéragi au moins autant de fois que la moyenne d'interaction.

# %%
moy_nb_inter=ratings_explicit['user_id'].value_counts().mean()
moy_nb_inter
# Out:
# 5.573819163292847

# %%
mask_rating = ratings_explicit['user_id'].value_counts() > 10

# %%
user_indexes=mask_rating[mask_rating].index

user_indexes
# Out:
# Index([ 11676,  98391, 153662, 189835,  23902,  76499, 171118, 235105,  16795,
#        248718,
#        ...
#        147947, 254995, 154031, 107540, 167761,  60703,   6115, 162861, 104759,
#        104925],
#       dtype='int64', name='user_id', length=6655)

# %%
ratings_tmp=ratings_explicit[ratings_explicit['user_id'].isin(user_indexes)]

# %%
ratings_tmp.reset_index(drop=True, inplace=True)

# %%
ratings_tmp
# Out:
#         user_id        ISBN  rating
# 0           183  9724509524       8
# 1           183  9728440170       9
# 2           183  9728440138       9
# 3           183  9728440057       7
# 4           183  9728440030       9
# ...         ...         ...     ...
# 288766   278851  067161746X       7
# 288767   278851  0440486599       5
# 288768   278851  0439050006       5
# 288769   278851  0380865610       5
# 288770   278851  0843106743       7
#
# [288771 rows x 3 columns]

# %% [markdown]
# Maintenant, on va faire pareil avec le nombre de livres qui a eu une interaction.

# %%
moy_books_inter=ratings_tmp['ISBN'].value_counts().mean()
moy_books_inter
# Out:
# 2.0066222404436136

# %%
mask_books = ratings_tmp['ISBN'].value_counts() > 10
book_indexes=mask_books[mask_books].index

# %%
ratings_tmp=ratings_tmp[ratings_tmp['ISBN'].isin(book_indexes)].reset_index(drop=True).copy()

ratings_tmp
# Out:
#        user_id        ISBN  rating
# 0          242  0553278223      10
# 1          243  0446364800       9
# 2          243  155874262X       5
# 3          243  0449006522       6
# 4          243  0446606383       6
# ...        ...         ...     ...
# 67400   278843  0060517794       7
# 67401   278843  0060173289       9
# 67402   278851  0894803700       5
# 67403   278851  1558531025       8
# 67404   278851  0440486599       5
#
# [67405 rows x 3 columns]

# %%
save_df_to_csv(ratings_tmp, '../../datasets/reco_datasets/collaborative_dataset_explicit.csv')
save_df_to_pickle(ratings_tmp, '../../datasets/reco_datasets/collaborative_dataset_explicit.pkl')

# %%
books_final = pd.read_csv(path+"Books.csv")
books_final.rename(columns={'Book-Title':'title', 'Book-Author': 'author','Year-Of-Publication':'year', 'Publisher':'publisher'}, inplace=True)
books_final.drop(columns=['Image-URL-S', 'Image-URL-M'], inplace=True)
books_final.head(10)
# Out:
#          ISBN                                              title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
# 5  0399135782                             The Kitchen God's Wife
# 6  0425176428  What If?: The World's Foremost Military Histor...
# 7  0671870432                                    PLEADING GUILTY
# 8  0679425608  Under the Black Flag: The Romance and the Real...
# 9  074322678X            Where You'll Find Me: And Other Stories
#
#                  author  year                   publisher  \
# 0    Mark P. O. Morford  2002     Oxford University Press
# 1  Richard Bruce Wright  2001       HarperFlamingo Canada
# 2          Carlo D'Este  1991             HarperPerennial
# 3      Gina Bari Kolata  1999        Farrar Straus Giroux
# 4       E. J. W. Barber  1999  W. W. Norton &amp; Company
# 5               Amy Tan  1991            Putnam Pub Group
# 6         Robert Cowley  2000    Berkley Publishing Group
# 7           Scott Turow  1993                  Audioworks
# 8       David Cordingly  1996                Random House
# 9           Ann Beattie  2002                    Scribner
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
# 5  http://images.amazon.com/images/P/0399135782.0...
# 6  http://images.amazon.com/images/P/0425176428.0...
# 7  http://images.amazon.com/images/P/0671870432.0...
# 8  http://images.amazon.com/images/P/0679425608.0...
# 9  http://images.amazon.com/images/P/074322678X.0...

# %%
ratings_tmp_books=ratings_tmp.merge(books_final, on='ISBN')

# %%
ratings_tmp_books
# Out:
#        user_id        ISBN  rating  \
# 0          242  0553278223      10
# 1          243  0446364800       9
# 2          243  155874262X       5
# 3          243  0449006522       6
# 4          243  0446606383       6
# ...        ...         ...     ...
# 66260   278843  0060517794       7
# 66261   278843  0060173289       9
# 66262   278851  0894803700       5
# 66263   278851  1558531025       8
# 66264   278851  0440486599       5
#
#                                                    title              author  \
# 0                                 The Martian Chronicles        RAY BRADBURY
# 1                                 The General's Daughter      Nelson DeMille
# 2      Chicken Soup for the Soul (Chicken Soup for th...       Jack Canfield
# 3                                    Manhattan Hunt Club           JOHN SAUL
# 4                                      The Midnight Club     James Patterson
# ...                                                  ...                 ...
# 66260                           Little Altars Everywhere       Rebecca Wells
# 66261   Divine Secrets of the Ya-Ya Sisterhood : A Novel       Rebecca Wells
# 66262                    14,000 Things to Be Happy About  Barbara Ann Kipfer
# 66263  Life's Little Instruction Book (Life's Little ...    H. Jackson Brown
# 66264                          Then Again, Maybe I Won't          JUDY BLUME
#
#        year              publisher  \
# 0      1984                Spectra
# 1      1993           Warner Books
# 2      1993  Health Communications
# 3      2002       Ballantine Books
# 4      1999          Warner Vision
# ...     ...                    ...
# 66260  2003            HarperTorch
# 66261  1996          HarperCollins
# 66262  1990     Workman Publishing
# 66263  1991          Thomas Nelson
# 66264  1986               Yearling
#
#                                              Image-URL-L
# 0      http://images.amazon.com/images/P/0553278223.0...
# 1      http://images.amazon.com/images/P/0446364800.0...
# 2      http://images.amazon.com/images/P/155874262X.0...
# 3      http://images.amazon.com/images/P/0449006522.0...
# 4      http://images.amazon.com/images/P/0446606383.0...
# ...                                                  ...
# 66260  http://images.amazon.com/images/P/0060517794.0...
# 66261  http://images.amazon.com/images/P/0060173289.0...
# 66262  http://images.amazon.com/images/P/0894803700.0...
# 66263  http://images.amazon.com/images/P/1558531025.0...
# 66264  http://images.amazon.com/images/P/0440486599.0...
#
# [66265 rows x 8 columns]

# %% [markdown]
# On a ainsi les notes et les livres correspondants avec l'image de couverture, ça pourra servir plus tard si on veut afficher le livre.

# %%
save_df_to_csv(ratings_tmp_books, '../../datasets/reco_datasets/ratings_with_books.csv')
save_df_to_pickle(ratings_tmp_books, '../../datasets/reco_datasets/ratings_with_books.pkl')

# %%
users.head()
# Out:
#    user_id                            location   age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
user_stats = ratings_explicit.groupby('user_id')['rating'].mean().reset_index()
user_stats.columns = ['user_id', 'user_avg_rating']

user_stats
# Out:
#        user_id  user_avg_rating
# 0            8         5.571429
# 1            9         6.000000
# 2           10         6.000000
# 3           12        10.000000
# 4           14         5.333333
# ...        ...              ...
# 77800   278846         8.000000
# 77801   278849         9.000000
# 77802   278851         6.500000
# 77803   278852         8.000000
# 77804   278854         7.000000
#
# [77805 rows x 2 columns]

# %%
users_avg_rating=users.merge(user_stats, on='user_id')

users_avg_rating
# Out:
#        user_id                         location   age  user_avg_rating
# 0            8         timmins, ontario, canada   NaN         5.571429
# 1            9       germantown, tennessee, usa   NaN         6.000000
# 2           10       albacete, wisconsin, spain  26.0         6.000000
# 3           12      fort bragg, california, usa   NaN        10.000000
# 4           14            mediapolis, iowa, usa   NaN         5.333333
# ...        ...                              ...   ...              ...
# 77800   278846         toronto, ontario, canada  23.0         8.000000
# 77801   278849      georgetown, ontario, canada  23.0         9.000000
# 77802   278851               dallas, texas, usa  33.0         6.500000
# 77803   278852  brisbane, queensland, australia  32.0         8.000000
# 77804   278854            portland, oregon, usa   NaN         7.000000
#
# [77805 rows x 4 columns]

# %%
df_avg=ratings_tmp.merge(users_avg_rating, on='user_id')
df_avg
# Out:
#        user_id        ISBN  rating                              location  \
# 0          242  0553278223      10  neuffen, baden-wuerttemberg, germany
# 1          243  0446364800       9           arden hills, minnesota, usa
# 2          243  155874262X       5           arden hills, minnesota, usa
# 3          243  0449006522       6           arden hills, minnesota, usa
# 4          243  0446606383       6           arden hills, minnesota, usa
# ...        ...         ...     ...                                   ...
# 67400   278843  0060517794       7          pismo beach, california, usa
# 67401   278843  0060173289       9          pismo beach, california, usa
# 67402   278851  0894803700       5                    dallas, texas, usa
# 67403   278851  1558531025       8                    dallas, texas, usa
# 67404   278851  0440486599       5                    dallas, texas, usa
#
#         age  user_avg_rating
# 0      37.0         8.545455
# 1       NaN         7.277778
# 2       NaN         7.277778
# 3       NaN         7.277778
# 4       NaN         7.277778
# ...     ...              ...
# 67400  28.0         7.700000
# 67401  28.0         7.700000
# 67402  33.0         6.500000
# 67403  33.0         6.500000
# 67404  33.0         6.500000
#
# [67405 rows x 6 columns]

# %% [markdown]
# Ici on a les informations basiques des utilisateurs encore présents dans le dataset ratings.

# %%
save_df_to_csv(df_avg, '../../datasets/reco_datasets/users_stats.csv')
save_df_to_pickle(df_avg, '../../datasets/reco_datasets/users_stats.pkl')

# %% [markdown]
# # Recommandation basée sur le contenu

# %% [markdown]
# ## Préparation des textes (TF-IDF, W2V, GloVe)

# %%
content_df=pd.read_pickle('../../datasets/reco_datasets/content_dataset.pkl')

# %%
# On nettoie légèrement le texte pour garder sa forme principale (dont accents etc)

content_df['title_clean'] = content_df['title'].apply(nettoyage_word2vec)
content_df['author_clean'] = content_df['author'].apply(nettoyage_word2vec)
content_df['publisher_clean'] = content_df['publisher'].apply(nettoyage_word2vec)
content_df['sujets_clean'] = content_df['sujets'].apply(nettoyage_word2vec)
content_df['description_clean'] = content_df['description'].apply(nettoyage_word2vec)

# %%
content_df['sujets_clean'] = content_df['sujets_clean'].apply(lambda x: " ".join(x) if isinstance(x, list) else "")

# %%
content_df.head()
# Out:
#          ISBN                                              title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 3  0393045218                             The Mummies of Urumchi
# 4  0425176428  What If?: The World's Foremost Military Histor...
#
#                  author  year                 publisher  \
# 0    Mark P. O. Morford  2002   Oxford University Press
# 1  Richard Bruce Wright  2001     HarperFlamingo Canada
# 2      Gina Bari Kolata  1999      Farrar Straus Giroux
# 3       E. J. W. Barber  1999    W. W. Norton & Company
# 4         Robert Cowley  2000  Berkley Publishing Group
#
#                                               sujets  \
# 0                             [mythology, classical]
# 1  [ontario, teachers, young, women, new, york, f...
# 2                [20th, history, century, influenza]
# 3  [antiquities, fabrics, prehistoric, textile, b...
# 4              [histories, wars, imaginary, battles]
#
#                                          description  \
# 0  An excellent primer on classical mythology for...
# 1  E-book extras: "Hero of the Humdrum": A profil...
# 2  The fascinating, true story of the world's dea...
# 3  In the museums of Urumchi, the wind-swept regi...
# 4  With its in-depth reflections on the monumenta...
#
#                                          title_clean          author_clean  \
# 0                                classical mythology      mark p o morford
# 1                                       clara callan  richard bruce wright
# 2  flu the story of the great influenza pandemic ...      gina bari kolata
# 3                             the mummies of urumchi          e j w barber
# 4  what if the world s foremost military historia...         robert cowley
#
#             publisher_clean  \
# 0   oxford university press
# 1     harperflamingo canada
# 2      farrar straus giroux
# 3        w w norton company
# 4  berkley publishing group
#
#                                         sujets_clean  \
# 0                                mythology classical
# 1  ontario teachers young women new york fiction ...
# 2                       th history century influenza
# 3  antiquities fabrics prehistoric textile bronze...
# 4                   histories wars imaginary battles
#
#                                    description_clean
# 0  an excellent primer on classical mythology for...
# 1  e book extras hero of the humdrum a profile of...
# 2  the fascinating true story of the world s dead...
# 3  in the museums of urumchi the wind swept regio...
# 4  with its in depth reflections on the monumenta...

# %%
save_df_to_pickle(content_df, '../../datasets/reco_datasets/content_dataset_w2v.pkl')

# %%
content_df['description_clean'].duplicated().sum()
# Out:
# 21381

# %%
content_df.drop_duplicates(subset=['description_clean'], inplace=True)

# %%
content_df.reset_index(drop=True, inplace=True)

# %%
content_df
# Out:
#              ISBN                                              title  \
# 0      0195153448                                Classical Mythology
# 1      0002005018                                       Clara Callan
# 2      0374157065  Flu: The Story of the Great Influenza Pandemic...
# 3      0393045218                             The Mummies of Urumchi
# 4      0425176428  What If?: The World's Foremost Military Histor...
# ...           ...                                                ...
# 57955  3462017942              Die Massenpsychologie des Faschismus.
# 57956  020130998X  The Unified Modeling Language Reference Manual...
# 57957  0231128444                      Slow Food(The Case For Taste)
# 57958  014002803X                                  Anti Death League
# 57959  0525447644                            From One to One Hundred
#
#                      author  year                    publisher  \
# 0        Mark P. O. Morford  2002      Oxford University Press
# 1      Richard Bruce Wright  2001        HarperFlamingo Canada
# 2          Gina Bari Kolata  1999         Farrar Straus Giroux
# 3           E. J. W. Barber  1999       W. W. Norton & Company
# 4             Robert Cowley  2000     Berkley Publishing Group
# ...                     ...   ...                          ...
# 57955         Wilhelm Reich  1986         Kiepenheuer & Witsch
# 57956        James Rumbaugh  1998  Addison-Wesley Professional
# 57957         Carlo Petrini  2003    Columbia University Press
# 57958         Kingsley Amis  1975                 Viking Press
# 57959            Teri Sloat  1991                 Dutton Books
#
#                                                   sujets  \
# 0                                 [mythology, classical]
# 1      [ontario, teachers, young, women, new, york, f...
# 2                    [20th, history, century, influenza]
# 3      [antiquities, fabrics, prehistoric, textile, b...
# 4                  [histories, wars, imaginary, battles]
# ...                                                  ...
# 57955                                                 []
# 57956    [software, computer, science, uml, development]
# 57957  [food, slow, gaststättengewerbe, ess, trinksit...
# 57958                         [general, modern, fiction]
# 57959                   [literature, counting, juvenile]
#
#                                              description  \
# 0      An excellent primer on classical mythology for...
# 1      E-book extras: "Hero of the Humdrum": A profil...
# 2      The fascinating, true story of the world's dea...
# 3      In the museums of Urumchi, the wind-swept regi...
# 4      With its in-depth reflections on the monumenta...
# ...                                                  ...
# 57955  **The Mass Psychology of Fascism** (German: *D...
# 57956  The Unified Modeling Language (UML) has rapidl...
# 57957  Discusses the history and spread of the Intern...
# 57958  Amid preparations for Operation Apollo, secret...
# 57959  Illustrations of people and animals introduce ...
#
#                                              title_clean  \
# 0                                    classical mythology
# 1                                           clara callan
# 2      flu the story of the great influenza pandemic ...
# 3                                 the mummies of urumchi
# 4      what if the world s foremost military historia...
# ...                                                  ...
# 57955               die massenpsychologie des faschismus
# 57956  the unified modeling language reference manual...
# 57957                       slow food the case for taste
# 57958                                  anti death league
# 57959                            from one to one hundred
#
#                author_clean              publisher_clean  \
# 0          mark p o morford      oxford university press
# 1      richard bruce wright        harperflamingo canada
# 2          gina bari kolata         farrar straus giroux
# 3              e j w barber           w w norton company
# 4             robert cowley     berkley publishing group
# ...                     ...                          ...
# 57955         wilhelm reich           kiepenheuer witsch
# 57956        james rumbaugh  addison wesley professional
# 57957         carlo petrini    columbia university press
# 57958         kingsley amis                 viking press
# 57959            teri sloat                 dutton books
#
#                                             sujets_clean  \
# 0                                    mythology classical
# 1      ontario teachers young women new york fiction ...
# 2                           th history century influenza
# 3      antiquities fabrics prehistoric textile bronze...
# 4                       histories wars imaginary battles
# ...                                                  ...
# 57955
# 57956          software computer science uml development
# 57957  food slow gaststattengewerbe ess trinksitte mo...
# 57958                             general modern fiction
# 57959                       literature counting juvenile
#
#                                        description_clean
# 0      an excellent primer on classical mythology for...
# 1      e book extras hero of the humdrum a profile of...
# 2      the fascinating true story of the world s dead...
# 3      in the museums of urumchi the wind swept regio...
# 4      with its in depth reflections on the monumenta...
# ...                                                  ...
# 57955  the mass psychology of fascism german die mass...
# 57956  the unified modeling language uml has rapidly ...
# 57957  discusses the history and spread of the intern...
# 57958  amid preparations for operation apollo secret ...
# 57959  illustrations of people and animals introduce ...
#
# [57960 rows x 12 columns]

# %%
save_df_to_pickle(content_df, '../../datasets/reco_datasets/content_dataset_sans_doublon_full.pkl')
save_df_to_csv(content_df, '../../datasets/reco_datasets/content_dataset_sans_doublon_full.csv')

# %%
conntent_df_sans_doublon=content_df.drop(columns=['title_clean', 'author_clean', 'publisher_clean', 'sujets_clean', 'description_clean'])

# %%
save_df_to_pickle(conntent_df_sans_doublon, '../../datasets/reco_datasets/content_dataset_sans_doublon.pkl')
save_df_to_csv(conntent_df_sans_doublon, '../../datasets/reco_datasets/content_dataset_sans_doublon.csv')

# %% [markdown]
# ## Utilisation de TF-IDF (pour faire une recherche dans le dataset)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
content_df=pd.read_pickle('../../datasets/reco_datasets/content_dataset_sans_doublon_full.pkl')

# %%
tfidf=TfidfVectorizer(ngram_range=(1, 3))
title_matrix=tfidf.fit_transform(content_df['title_clean'])

# %%
title_matrix.shape
# Out:
# (68631, 398073)

# %%
from sklearn.metrics.pairwise import cosine_similarity

def search(title):
    title = nettoyage_texte(title)
    vec = tfidf.transform([title])
    similarite = cosine_similarity(vec, title_matrix).flatten()
    indices = np.argpartition(similarite, -5)[-5:]
    res=content_df.iloc[indices][::-1][['ISBN',	'title', 'author', 'year', 'publisher']]

    return res

# %%
search('Harry Potter')
# Out:
#              ISBN                                              title  \
# 12059  043965548X  Harry Potter and the Prisoner of Azkaban (Harr...
# 22877  0439554896  Harry Potter and the Chamber of Secrets (Harry...
# 39974  1594130027  Harry Potter and the Prisoner of Azkaban (Harr...
# 9505   2070541304  Harry Potter, tome 3 : Harry Potter et le Pris...
# 41176  2070541290  Harry Potter, tome 2 : Harry Potter et la Cham...
#
#                   author  year               publisher
# 12059       J.K. Rowling  2004   Scholastic Paperbacks
# 22877      J. K. Rowling  2003  Arthur A. Levine Books
# 39974      J. K. Rowling  2003       Large Print Press
# 9505   Joanne K. Rowling  1999               Gallimard
# 41176  Joanne K. Rowling  1999               Gallimard

# %%
import ipywidgets as widgets
from IPython.display import display

book_input = widgets.Text(
    value = ' ',
    description = 'Book Title',
    disabled=False
)

book_list=widgets.Output()

def on_type(data):
    with book_list:
        book_list.clear_output()
        title = data["new"] 
        if len(title) > 5:
            display(search(title))

book_input.observe(on_type, names='value')

display(book_input, book_list)
# Out:
# Text(value=' ', description='Book Title')
# Output()

# %%
tfidf.get_feature_names_out()[:20]
# Out:
# array(['00', '00 mystery', '00 mystery at', '00 on', '00 on houseboat',
#        '001', '001 double', '001 double love', '001 with',
#        '001 with cdrom', '002', '002 secrets', '002 secrets sweet', '003',
#        '003 playing', '003 playing wfire', '004', '004 power',
#        '004 power play', '005'], dtype=object)

# %% [markdown]
# ## Entrainement de Word2Vec

# %%
content_df=pd.read_pickle('../../datasets/reco_datasets/content_dataset_sans_doublon_full.pkl')

# %% [markdown]
# On va créer les tokens des mots des textes.

# %%
tqdm.pandas(desc="Tokenisation des textes")

titles=content_df['title_clean'].progress_apply(gensim.utils.simple_preprocess)
subjects_proc=content_df['sujets_clean'].progress_apply(gensim.utils.simple_preprocess)
desc_proc=content_df['description_clean'].progress_apply(gensim.utils.simple_preprocess)
# Out:
# Tokenisation des textes: 100%|██████████| 57960/57960 [00:01<00:00, 55562.28it/s]
# Tokenisation des textes: 100%|██████████| 57960/57960 [00:00<00:00, 96390.35it/s]
# Tokenisation des textes: 100%|██████████| 57960/57960 [00:05<00:00, 10001.95it/s]

# %%
#ici on ajoute une séparation pour aider le modèle à différencier le type de contenu qu'il lit

text_fusion=[]

for t, s, d in zip(titles, subjects_proc, desc_proc):
    text_fusion.append(['<TITLE>'] + t + ['<SUBJECTS>'] + s + ['<DESC>'] + d)

# %%
w2v=gensim.models.Word2Vec(sentences=text_fusion, vector_size=150, window=10, workers=10, min_count=5)

# %%
w2v.save("../../models/word2vec_model_text_fusion.model")

# %%
fusion_token=[get_text_vector(book, w2v) for book in tqdm(text_fusion)]
# Out:
# 100%|██████████| 57960/57960 [00:14<00:00, 3893.81it/s]

# %%
fusion_token_serie=pd.Series(fusion_token)

# %%
fusion_token_serie.head()
# Out:
# 0    [-0.06411282, 0.22272427, -0.44902217, -0.2710...
# 1    [0.16263367, 0.1321265, 0.28438684, -0.3819983...
# 2    [0.56824416, 0.16446283, -0.12623402, 0.009544...
# 3    [0.16337354, 0.15990022, -0.34316146, -0.27643...
# 4    [0.5493796, 0.015232784, -0.13083039, -0.12401...
# dtype: object

# %%
X=np.vstack(fusion_token_serie)

# %%
with open('../../datasets/embeddings_w2v.pkl', 'wb') as f:
    pickle.dump(X, f)

# %% [markdown]
# ## Utilisation de GloVe

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text_fusion)

# %%
print("Nombre de mots dans le dictionnaire :", len(tokenizer.word_index))
# Out:
# Nombre de mots dans le dictionnaire : 120413

# %%
from gensim.scripts.glove2word2vec import glove2word2vec
from gensim.models import KeyedVectors

embedding_dim = 200

glove_path = f'../../models/glove/glove.6B.{embedding_dim}d.txt'
word2vec_output_file = f'../../models/glove/glove.6B.{embedding_dim}d.word2vec.txt'

# %%
glove2word2vec(glove_path, word2vec_output_file)
# Out:
# C:\Users\tarek\AppData\Local\Temp\ipykernel_19924\2573687595.py:1: DeprecationWarning: Call to deprecated `glove2word2vec` (KeyedVectors.load_word2vec_format(.., binary=False, no_header=True) loads GLoVE text vectors.).
#   glove2word2vec(glove_path, word2vec_output_file)
# (400000, 200)

# %%
glove = KeyedVectors.load_word2vec_format(word2vec_output_file, binary=False)

# %%
fusion_token_glove=[sentence_vector(book, glove) for book in tqdm(text_fusion)]
# Out:
# 100%|██████████| 57960/57960 [00:14<00:00, 3976.88it/s]

# %%
fusion_token_glove[0]
# Out:
# array([ 0.30755815,  0.10562591,  0.17970185, -0.3679312 ,  0.3016246 ,
#        -0.02384786, -0.457119  ,  0.15751502,  0.18150266, -0.14326148,
#         0.15395962,  0.33609253, -0.00537747, -0.19615272,  0.20035541,
#         0.08767714,  0.1716869 ,  0.3529484 ,  0.02919114, -0.21337925,
#         0.44143882,  2.0086691 ,  0.05645609, -0.3886385 ,  0.31383142,
#         0.19095032, -0.02020439, -0.20434809,  0.16358308,  0.05781369,
#        -0.08092288,  0.29954487, -0.12072979, -0.29630747,  0.29977554,
#        -0.218659  , -0.40371227, -0.34025308,  0.12339522, -0.25631747,
#         0.03560612, -0.40788114,  0.02046514,  0.06516082, -0.10348261,
#         0.16734011,  0.3651881 , -0.10212114,  0.23175912,  0.2390988 ,
#        -0.36878094,  0.07891554, -0.02370057,  0.27292237,  0.14671047,
#         0.0394091 ,  0.12512803,  0.28383404, -0.02325648,  0.0538092 ,
#        -0.33994094, -0.01931171, -0.36128017,  0.13571976,  0.12617655,
#        -0.05602182,  0.1582334 ,  0.33777148,  0.22782296, -0.14616068,
#         0.12942077, -0.00263892, -0.07642405,  0.17377666, -0.03138719,
#        -0.10634466, -0.179174  , -0.14093925, -0.08352651, -0.2823858 ,
#         0.32696813, -0.1420898 , -0.35108846,  0.08353228,  0.21547318,
#         0.09277687, -0.03673124, -0.12062625,  0.84788895, -0.4547583 ,
#         0.1894001 , -0.02731223,  0.38388714, -0.14008395, -0.16579276,
#        -0.32881933,  0.226088  , -0.13242625, -0.23366556, -0.02088766,
#        -0.05716655,  0.17856948, -0.14127968,  0.19790901,  0.23139842,
#        -0.3210155 , -0.14079535,  0.607632  , -0.22867048,  0.13356555,
#         0.09747182, -0.20190923,  0.04102743, -0.07941069,  0.04054895,
#         0.09077766, -0.1539083 ,  0.19788305, -0.33931717, -0.06667962,
#         0.16017385,  0.1624642 , -0.00308329,  0.08859607,  0.12194068,
#        -0.21044831,  0.12995818,  0.17781103,  0.07974782,  0.01039662,
#        -0.2100856 ,  0.01594863,  0.19270536, -0.01235405, -0.01326412,
#        -0.04397933, -0.01648379, -0.2587501 , -0.14007157, -0.2776379 ,
#         0.03387348, -0.27736324,  0.14283898, -0.18445984,  0.9912366 ,
#        -0.07859271,  0.06163403, -0.23277247, -0.05859548,  0.05870162,
#         0.00842657,  0.3228141 , -0.18757886, -0.09408189,  0.098446  ,
#        -0.26902655,  0.13554856,  0.04412189, -0.10847386,  0.0281003 ,
#         0.19016625,  0.22462706,  0.05433789, -0.0896627 ,  0.24380259,
#         0.00495405, -0.20562766, -0.0694348 , -0.43845195,  0.54919446,
#        -0.13878137,  0.03114902,  0.13621072,  0.18248029,  0.02381258,
#        -0.07937008, -0.1714729 , -0.14651486,  0.01501599,  0.1706259 ,
#         0.5675037 , -0.18064098, -0.06311761, -0.08473307, -0.01965972,
#         0.01962695,  0.04537106,  0.00627548,  0.09409666, -0.00544321,
#        -0.19083361,  0.1281107 ,  0.05567523,  0.03696948,  0.11322109,
#        -0.23165491, -0.26195472,  0.12969396,  0.00673639,  0.2008201 ],
#       dtype=float32)

# %%
fusion_token_glove_serie=pd.Series(fusion_token_glove)
fusion_token_glove_serie
# Out:
# 0        [0.30755815, 0.10562591, 0.17970185, -0.367931...
# 1        [0.017109556, 0.28028125, -0.0817375, -0.22292...
# 2        [0.03869363, 0.04833352, -0.04343567, -0.24260...
# 3        [0.18290083, 0.0658717, -0.09196495, -0.213143...
# 4        [0.059435833, 0.19990379, -0.04997457, -0.1633...
#                                ...
# 57955    [-0.035772197, 0.13296166, 0.039128445, -0.106...
# 57956    [0.15818211, 0.27699795, 0.07344365, -0.109747...
# 57957    [0.055929236, 0.1144517, -0.1385344, -0.040413...
# 57958    [0.0904096, -0.018649003, -0.13404374, -0.1886...
# 57959    [0.027832823, 0.12822556, -0.16156122, -0.1185...
# Length: 57960, dtype: object

# %%
X_glove=np.vstack(fusion_token_glove_serie)

X_glove
# Out:
# array([[ 0.30755815,  0.10562591,  0.17970185, ...,  0.12969396,
#          0.00673639,  0.2008201 ],
#        [ 0.01710956,  0.28028125, -0.0817375 , ..., -0.00422918,
#          0.15208262,  0.13644333],
#        [ 0.03869363,  0.04833352, -0.04343567, ...,  0.07369021,
#         -0.08564171,  0.1066957 ],
#        ...,
#        [ 0.05592924,  0.1144517 , -0.1385344 , ...,  0.02251309,
#          0.00438884,  0.18385674],
#        [ 0.0904096 , -0.018649  , -0.13404374, ...,  0.03422218,
#          0.01244916,  0.06070415],
#        [ 0.02783282,  0.12822556, -0.16156122, ...,  0.20009831,
#         -0.14493118,  0.19678748]])

# %%
with open('../../datasets/embeddings_glove.pkl', 'wb') as f:
    pickle.dump(X_glove, f)

# %% [markdown]
# ## Utilisation de BERT

# %% [markdown]
# ### Nettoyage des textes (pour garder plus de contexte)

# %%
content_df=pd.read_pickle('../../datasets/reco_datasets/content_dataset_sans_doublon_full.pkl')

# %%
content_df['title_clean'] = content_df['title'].apply(nettoyage_leger)
content_df['author_clean'] = content_df['author'].apply(nettoyage_leger)
content_df['publisher_clean'] = content_df['publisher'].apply(nettoyage_leger)
content_df['sujets_clean'] = content_df['sujets'].apply(nettoyage_leger)
content_df['description_clean'] = content_df['description'].apply(nettoyage_leger)

# %%
content_df.head()
# Out:
#          ISBN                                              title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 3  0393045218                             The Mummies of Urumchi
# 4  0425176428  What If?: The World's Foremost Military Histor...
#
#                  author  year                 publisher  \
# 0    Mark P. O. Morford  2002   Oxford University Press
# 1  Richard Bruce Wright  2001     HarperFlamingo Canada
# 2      Gina Bari Kolata  1999      Farrar Straus Giroux
# 3       E. J. W. Barber  1999    W. W. Norton & Company
# 4         Robert Cowley  2000  Berkley Publishing Group
#
#                                               sujets  \
# 0                             [mythology, classical]
# 1  [ontario, teachers, young, women, new, york, f...
# 2                [20th, history, century, influenza]
# 3  [antiquities, fabrics, prehistoric, textile, b...
# 4              [histories, wars, imaginary, battles]
#
#                                          description  \
# 0  An excellent primer on classical mythology for...
# 1  E-book extras: "Hero of the Humdrum": A profil...
# 2  The fascinating, true story of the world's dea...
# 3  In the museums of Urumchi, the wind-swept regi...
# 4  With its in-depth reflections on the monumenta...
#
#                                          title_clean          author_clean  \
# 0                                Classical Mythology    Mark P. O. Morford
# 1                                       Clara Callan  Richard Bruce Wright
# 2  Flu: The Story of the Great Influenza Pandemic...      Gina Bari Kolata
# 3                             The Mummies of Urumchi       E. J. W. Barber
# 4  What If?: The World's Foremost Military Histor...         Robert Cowley
#
#             publisher_clean  \
# 0   Oxford University Press
# 1     HarperFlamingo Canada
# 2      Farrar Straus Giroux
# 3    W. W. Norton & Company
# 4  Berkley Publishing Group
#
#                                         sujets_clean  \
# 0                             [mythology, classical]
# 1  [ontario, teachers, young, women, new, york, f...
# 2                [20th, history, century, influenza]
# 3  [antiquities, fabrics, prehistoric, textile, b...
# 4              [histories, wars, imaginary, battles]
#
#                                    description_clean
# 0  An excellent primer on classical mythology for...
# 1  E-book extras: "Hero of the Humdrum": A profil...
# 2  The fascinating, true story of the world's dea...
# 3  In the museums of Urumchi, the wind-swept regi...
# 4  With its in-depth reflections on the monumenta...

# %%
content_df.shape
# Out:
# (57960, 12)

# %%
titles=content_df['title_clean'].tolist()

titles[:10]
# Out:
# ['Classical Mythology',
#  'Clara Callan',
#  'Flu: The Story of the Great Influenza Pandemic of 1918 and the Search for the Virus That Caused It',
#  'The Mummies of Urumchi',
#  "What If?: The World's Foremost Military Historians Imagine What Might Have Been",
#  'PLEADING GUILTY',
#  'Goodbye to the Buttermilk Sky',
#  'Mary-Kate & Ashley Switching Goals (Mary-Kate and Ashley Starring in)',
#  'Flood : Mississippi 1927',
#  'Wild Animus']

# %%
subjects=content_df['sujets_clean'].tolist()

subjects[:10]
# Out:
# [['mythology', 'classical'],
#  ['ontario',
#   'teachers',
#   'young',
#   'women',
#   'new',
#   'york',
#   'fiction',
#   'sisters',
#   'actresses'],
#  ['20th', 'history', 'century', 'influenza'],
#  ['antiquities',
#   'fabrics',
#   'prehistoric',
#   'textile',
#   'bronze',
#   'age',
#   'zizhiqu',
#   'uygur',
#   'tarim',
#   'xinjiang',
#   'china',
#   'basin',
#   'mummies'],
#  ['histories', 'wars', 'imaginary', 'battles'],
#  [],
#  ['alabama', 'farm', 'married', 'depressions', 'life', 'fiction', 'women'],
#  ['soccer',
#   'twins',
#   'tie',
#   'movie',
#   'books',
#   'juvenile',
#   'sports',
#   'recreation',
#   'general',
#   'grades',
#   'television',
#   'fiction',
#   'stories',
#   'ages',
#   'children'],
#  ['survival', 'friends', 'americans', 'best', 'floods', 'fiction', 'african'],
#  ['adventure',
#   'alaska',
#   'national',
#   'preserve',
#   'elias',
#   'popular',
#   'american',
#   'saint',
#   'general',
#   'wrangell',
#   'spiritual',
#   'park',
#   'literary',
#   'fiction',
#   'life',
#   'modern',
#   'metaphysics']]

# %%
subjects_text = [" ".join(tokens) for tokens in subjects]

subjects_text[:10]
# Out:
# ['mythology classical',
#  'ontario teachers young women new york fiction sisters actresses',
#  '20th history century influenza',
#  'antiquities fabrics prehistoric textile bronze age zizhiqu uygur tarim xinjiang china basin mummies',
#  'histories wars imaginary battles',
#  '',
#  'alabama farm married depressions life fiction women',
#  'soccer twins tie movie books juvenile sports recreation general grades television fiction stories ages children',
#  'survival friends americans best floods fiction african',
#  'adventure alaska national preserve elias popular american saint general wrangell spiritual park literary fiction life modern metaphysics']

# %%
descriptions = content_df['description_clean'].tolist()

descriptions[:10]
# Out:
# ['An excellent primer on classical mythology for readers who have little or no background of classical knowledge.',
#  'E-book extras: "Hero of the Humdrum": A profile of Richard B. Wright by John Bemrose; prize citations.It is 1934, and in a small town in Canada, Clara Callan reluctantly takes leave of her sister, Nora, who is bound for the show business world of New York. Richard B. Wright\'s acclaimed novel, winner in 2001 of Canada\'s two most prestigious literary awards, is a mesmerizing tribute to friendship and sisterhood, romance and redemption.Winner in 2001 of Canada\'s two most prestigious literary awards -- the Governor General\'s Award and the Giller Prize -- Richard B. Wright\'s celebrated novel Clara Callan is the powerful, moving story of two sisters and their life-changing experiences on the eve of World War II.',
#  "The fascinating, true story of the world's deadliest disease. In 1918, the Great Flu Epidemic felled the young and healthy virtually overnight. An estimated forty million people died as the epidemic raged. Children were left orphaned and families were devastated. As many American soldiers were killed by the 1918 flu as were killed in battle during World War I. And no area of the globe was safe. Eskimos living in remote outposts in the frozen tundra were sickened and killed by the flu in such numbers that entire villages were wiped out. Scientists have recently rediscovered shards of the flu virus frozen in Alaska and preserved in scraps of tissue in a government warehouse. The author unravels the mystery of this lethal virus with the high drama of a great adventure story. Delving into the history of the flu and previous epidemics, detailing the science and the latest understanding of this mortal disease, she addresses the prospects for a great epidemic recurring, and, most important, what can be done to prevent it.",
#  'In the museums of Urumchi, the wind-swept regional capital of the Uyghur Autonomous Region in Western China, a collection of ancient mummies date back as far as 4,000 years - contemporary to the famous Egyptian mummies, but even more beautifully preserved, especially their clothing. Surprisingly, these prehistoric people are not Asian but Caucasoid - tall and large-nosed and blond with thick beards and round eyes (probably blue). What were these blond Caucasians doing in the heart of Asia? Where did they come from and what language did they speak? Might they be related to a "lost tribe" of Indo-Europeans known from later inscriptions? Few gifts are to be found in the graves of Urumchi, making it difficult for archaeologists to pinpoint cultural connections from clues offered by pottery and tools. But their clothes - woolens that rarely survive more than a few centurieshave been preserved as brightly hued as the day they were woven. Elizabeth Wayland Barber describes these remarkable mummies, their clothing, their sheepherding ways, and their path to this remote, mysterious, and forbidding place. She pieces together their history and peculiar Western connections from both what she saw in Urumchi and the testimony of explorers who traveled along the Silk Road a century earlier.',
#  'With its in-depth reflections on the monumental events of the past, this amazing book of essays ponders what might have been if things had gone differently in history. Featuring Stephen J. Ambrose, John Keegan, and many others. "Historians and inquisitive laymen alike love to ponder the dramatic what-its of history. In these twenty never-before-published essays, some of the keenest minds of our time ask the big, tantalizing questions: Where might we be if history had not unfolded the way it did? Why, how, and when was our fortune made real? The answers are surprising, sometimes frightening, and always entertaining."--BOOK JACKET. "In addition to the essays, fifteen sidebars by such authors as Caleb Carr, Tom Wicker, David Fromkin, and Ted Morgan illuminate in brief other world-changing episodes."--BOOK JACKET.',
#  '"Kindle County, Where skies are generally gray and the truth is seldom simple, is one of the most renowned and fascinating locales in contemporary American fiction. In Pleading Guilty Scott Turow takes us there again, in an edge-of-the-chair story rife with indelible characters and riveting suspense - 1993\'s most unforgettable reading experience." "Our guide is McCormack A. "Mack" Malloy, fiftyish ex-cop, almost ex-drunk, and partner-on-the-wane at Gage & Griswell, one of Kindle County\'s top-notch law firms, who has been charged by the firm\'s Oversight Committee with a highly sensitive task. Bert Kamin, G & G\'s gifted, erratic, impossibly combative star litigator, has been missing for weeks. Also missing is $5.6 million from a fund established to settle a massive air-disaster class-action suit against TransNational Airlines, the world\'s largest carrier and G & G\'s biggest client. The Committee needs Mack to find Bert and the money. Immediately." "His search takes us into the inner sanctums of G & G, where Mack\'s close-to-the-vest partners - among them his good friend and sometime bedmate Emilia "Brushy" Bruccia - jockey and plot. He ventures into the dark heart of the city itself, to the Russian bath in the far West End, where the mysterious Kam Roberts has left tracks. Before long he runs up against his former beat partner and longtime nemesis, the odious Pigeyes. And a cold corpse." "Mack is foul-mouthed, expansive, and sensual, weighed down by a profound familiarity with the ways of the world and his own ineradicable weaknesses, yet blessed with an incorrigible black-Irish sense of humor. He carries secrets of his own and knows that, as the police are fond of saying, there are no victims. Lovable, unreliable, a master sleuth, and an inimitable guide to an ominous and enthralling world, he may well be Scott Turow\'s supreme fictional creation to date."--BOOK JACKET.',
#  'Here is novelist Lee Smith \'s description on the 1994 edition\'s jacket: "This novel is about identity and community as much as it is about passion and morality. It deserves many, many readers. Julia Oliver captures those hot days of Alabama in the \'30s better than anybody, and all the complications of race and class and place." The following is found on the jacket flap of the 1994 Black Belt Press edition: Goodbye to the Buttermilk Sky is set on a picturesque cotton farm between two small towns in central Alabama, during the summer of 1938, when the Depression and the boll weevil ruled the economy; religion was polarized between rival sects of Methodists and Baptists; and gossip overheard on party lies was obligingly passed on, even by the telephone operator. The young farm wife Callie Tatum\'s affair with an insurance salesman from Birmingham sets off a chain of events, including rape and murder, that explode against the pastoral backdrop like fireworks. Readers will not soon forget Callie Tatum, who during this fateful summer evolves from naivete into a maturity and independence that make her a contemporary in spirit.',
#  'Emma Stanton is a boy magnet. Her twin sister, Sam, is an all-star athlete. So what do they do when Emma wants to get closer to her sports-crazed dad, and Sam wants to catch the attention of the cutest boy in school? Simple. Switch places! It seems like the perfect plan. Emma pretends to be Sam on the soccer field, while Sam goes on dates as Emma. But how long can the girls keep their secret? And what will happen when the truth comes out?',
#  "When the raging Mississippi threatens their secret cache of hard-earned nickels and pennies, Molly Bride and Garrett Wood risk their lives to retrieve the money that's their escape from the grinding poverty of their lives as sharecroppers.",
#  'How far would you go to find yourself? That\'s the question author Rich Shapero poses in his provocative debut novel about one man\'s obsessive quest for the foundations of the heart. Sam Altman, disillusioned with the answer of the 60s but inspired by his love for the mercurial Lindy, rejects a normal life and sets out to live in a new world of "inexhaustible desire." His unleashed and increasingly unhinged imagination drives the young lovers first to Seattle, than farther north, to the remote Alaskan wilderness. There, Sam grows progressively fascinated with the mountain ram, which seems to embody the passion and wisdom he seeks to possess. On the unforgiving ridges of Mt. Wrangell, alone with his dangerous ideas, Sam, who has changed his name to Ransom, brings his inspiration to life, transforming himself into a wild creature pursued by a pack of strangely familiar wolves. Is Ransom inspired by a transcendent truth, or prey to a misguided fantasy? As his grip on reality weakens, the reader shares Ransom\'s fears, his hopes, and his extraordinary discoveries. *Wild Animus* is a search for the primordial and a journey to the breaking point. It is a story of love and sacrifice, of obsession, of finding the limits of the heart and going one step farther.']

# %%
authors=content_df['author_clean'].tolist()

authors[:10]
# Out:
# ['Mark P. O. Morford',
#  'Richard Bruce Wright',
#  'Gina Bari Kolata',
#  'E. J. W. Barber',
#  'Robert Cowley',
#  'Scott Turow',
#  'Julia Oliver',
#  'Mary-Kate & Ashley Olsen',
#  'Kathleen Duey',
#  'Rich Shapero']

# %%
text_fusion_bert=[]

for t, s, d in zip(titles, subjects_text, descriptions):
    fusion = f"Title : {t}, Subjects : {s}, Description : {d}"
    text_fusion_bert.append(fusion)

# %%
text_fusion_bert[:10]
# Out:
# ['Title : Classical Mythology, Subjects : mythology classical, Description : An excellent primer on classical mythology for readers who have little or no background of classical knowledge.',
#  'Title : Clara Callan, Subjects : ontario teachers young women new york fiction sisters actresses, Description : E-book extras: "Hero of the Humdrum": A profile of Richard B. Wright by John Bemrose; prize citations.It is 1934, and in a small town in Canada, Clara Callan reluctantly takes leave of her sister, Nora, who is bound for the show business world of New York. Richard B. Wright\'s acclaimed novel, winner in 2001 of Canada\'s two most prestigious literary awards, is a mesmerizing tribute to friendship and sisterhood, romance and redemption.Winner in 2001 of Canada\'s two most prestigious literary awards -- the Governor General\'s Award and the Giller Prize -- Richard B. Wright\'s celebrated novel Clara Callan is the powerful, moving story of two sisters and their life-changing experiences on the eve of World War II.',
#  "Title : Flu: The Story of the Great Influenza Pandemic of 1918 and the Search for the Virus That Caused It, Subjects : 20th history century influenza, Description : The fascinating, true story of the world's deadliest disease. In 1918, the Great Flu Epidemic felled the young and healthy virtually overnight. An estimated forty million people died as the epidemic raged. Children were left orphaned and families were devastated. As many American soldiers were killed by the 1918 flu as were killed in battle during World War I. And no area of the globe was safe. Eskimos living in remote outposts in the frozen tundra were sickened and killed by the flu in such numbers that entire villages were wiped out. Scientists have recently rediscovered shards of the flu virus frozen in Alaska and preserved in scraps of tissue in a government warehouse. The author unravels the mystery of this lethal virus with the high drama of a great adventure story. Delving into the history of the flu and previous epidemics, detailing the science and the latest understanding of this mortal disease, she addresses the prospects for a great epidemic recurring, and, most important, what can be done to prevent it.",
#  'Title : The Mummies of Urumchi, Subjects : antiquities fabrics prehistoric textile bronze age zizhiqu uygur tarim xinjiang china basin mummies, Description : In the museums of Urumchi, the wind-swept regional capital of the Uyghur Autonomous Region in Western China, a collection of ancient mummies date back as far as 4,000 years - contemporary to the famous Egyptian mummies, but even more beautifully preserved, especially their clothing. Surprisingly, these prehistoric people are not Asian but Caucasoid - tall and large-nosed and blond with thick beards and round eyes (probably blue). What were these blond Caucasians doing in the heart of Asia? Where did they come from and what language did they speak? Might they be related to a "lost tribe" of Indo-Europeans known from later inscriptions? Few gifts are to be found in the graves of Urumchi, making it difficult for archaeologists to pinpoint cultural connections from clues offered by pottery and tools. But their clothes - woolens that rarely survive more than a few centurieshave been preserved as brightly hued as the day they were woven. Elizabeth Wayland Barber describes these remarkable mummies, their clothing, their sheepherding ways, and their path to this remote, mysterious, and forbidding place. She pieces together their history and peculiar Western connections from both what she saw in Urumchi and the testimony of explorers who traveled along the Silk Road a century earlier.',
#  'Title : What If?: The World\'s Foremost Military Historians Imagine What Might Have Been, Subjects : histories wars imaginary battles, Description : With its in-depth reflections on the monumental events of the past, this amazing book of essays ponders what might have been if things had gone differently in history. Featuring Stephen J. Ambrose, John Keegan, and many others. "Historians and inquisitive laymen alike love to ponder the dramatic what-its of history. In these twenty never-before-published essays, some of the keenest minds of our time ask the big, tantalizing questions: Where might we be if history had not unfolded the way it did? Why, how, and when was our fortune made real? The answers are surprising, sometimes frightening, and always entertaining."--BOOK JACKET. "In addition to the essays, fifteen sidebars by such authors as Caleb Carr, Tom Wicker, David Fromkin, and Ted Morgan illuminate in brief other world-changing episodes."--BOOK JACKET.',
#  'Title : PLEADING GUILTY, Subjects : , Description : "Kindle County, Where skies are generally gray and the truth is seldom simple, is one of the most renowned and fascinating locales in contemporary American fiction. In Pleading Guilty Scott Turow takes us there again, in an edge-of-the-chair story rife with indelible characters and riveting suspense - 1993\'s most unforgettable reading experience." "Our guide is McCormack A. "Mack" Malloy, fiftyish ex-cop, almost ex-drunk, and partner-on-the-wane at Gage & Griswell, one of Kindle County\'s top-notch law firms, who has been charged by the firm\'s Oversight Committee with a highly sensitive task. Bert Kamin, G & G\'s gifted, erratic, impossibly combative star litigator, has been missing for weeks. Also missing is $5.6 million from a fund established to settle a massive air-disaster class-action suit against TransNational Airlines, the world\'s largest carrier and G & G\'s biggest client. The Committee needs Mack to find Bert and the money. Immediately." "His search takes us into the inner sanctums of G & G, where Mack\'s close-to-the-vest partners - among them his good friend and sometime bedmate Emilia "Brushy" Bruccia - jockey and plot. He ventures into the dark heart of the city itself, to the Russian bath in the far West End, where the mysterious Kam Roberts has left tracks. Before long he runs up against his former beat partner and longtime nemesis, the odious Pigeyes. And a cold corpse." "Mack is foul-mouthed, expansive, and sensual, weighed down by a profound familiarity with the ways of the world and his own ineradicable weaknesses, yet blessed with an incorrigible black-Irish sense of humor. He carries secrets of his own and knows that, as the police are fond of saying, there are no victims. Lovable, unreliable, a master sleuth, and an inimitable guide to an ominous and enthralling world, he may well be Scott Turow\'s supreme fictional creation to date."--BOOK JACKET.',
#  'Title : Goodbye to the Buttermilk Sky, Subjects : alabama farm married depressions life fiction women, Description : Here is novelist Lee Smith \'s description on the 1994 edition\'s jacket: "This novel is about identity and community as much as it is about passion and morality. It deserves many, many readers. Julia Oliver captures those hot days of Alabama in the \'30s better than anybody, and all the complications of race and class and place." The following is found on the jacket flap of the 1994 Black Belt Press edition: Goodbye to the Buttermilk Sky is set on a picturesque cotton farm between two small towns in central Alabama, during the summer of 1938, when the Depression and the boll weevil ruled the economy; religion was polarized between rival sects of Methodists and Baptists; and gossip overheard on party lies was obligingly passed on, even by the telephone operator. The young farm wife Callie Tatum\'s affair with an insurance salesman from Birmingham sets off a chain of events, including rape and murder, that explode against the pastoral backdrop like fireworks. Readers will not soon forget Callie Tatum, who during this fateful summer evolves from naivete into a maturity and independence that make her a contemporary in spirit.',
#  'Title : Mary-Kate & Ashley Switching Goals (Mary-Kate and Ashley Starring in), Subjects : soccer twins tie movie books juvenile sports recreation general grades television fiction stories ages children, Description : Emma Stanton is a boy magnet. Her twin sister, Sam, is an all-star athlete. So what do they do when Emma wants to get closer to her sports-crazed dad, and Sam wants to catch the attention of the cutest boy in school? Simple. Switch places! It seems like the perfect plan. Emma pretends to be Sam on the soccer field, while Sam goes on dates as Emma. But how long can the girls keep their secret? And what will happen when the truth comes out?',
#  "Title : Flood : Mississippi 1927, Subjects : survival friends americans best floods fiction african, Description : When the raging Mississippi threatens their secret cache of hard-earned nickels and pennies, Molly Bride and Garrett Wood risk their lives to retrieve the money that's their escape from the grinding poverty of their lives as sharecroppers.",
#  'Title : Wild Animus, Subjects : adventure alaska national preserve elias popular american saint general wrangell spiritual park literary fiction life modern metaphysics, Description : How far would you go to find yourself? That\'s the question author Rich Shapero poses in his provocative debut novel about one man\'s obsessive quest for the foundations of the heart. Sam Altman, disillusioned with the answer of the 60s but inspired by his love for the mercurial Lindy, rejects a normal life and sets out to live in a new world of "inexhaustible desire." His unleashed and increasingly unhinged imagination drives the young lovers first to Seattle, than farther north, to the remote Alaskan wilderness. There, Sam grows progressively fascinated with the mountain ram, which seems to embody the passion and wisdom he seeks to possess. On the unforgiving ridges of Mt. Wrangell, alone with his dangerous ideas, Sam, who has changed his name to Ransom, brings his inspiration to life, transforming himself into a wild creature pursued by a pack of strangely familiar wolves. Is Ransom inspired by a transcendent truth, or prey to a misguided fantasy? As his grip on reality weakens, the reader shares Ransom\'s fears, his hopes, and his extraordinary discoveries. *Wild Animus* is a search for the primordial and a journey to the breaking point. It is a story of love and sacrifice, of obsession, of finding the limits of the heart and going one step farther.']

# %% [markdown]
# ### Ajout d'un modèle TFIDF pour la recherche de livre

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
tfidf=TfidfVectorizer(ngram_range=(1, 3))
title_matrix=tfidf.fit_transform(content_df['title_clean'])

# %%
def search(title):
    title = nettoyage_texte(title)
    vec = tfidf.transform([title])
    similarite = cosine_similarity(vec, title_matrix).flatten()
    indices = np.argpartition(similarite, -1)[-1:]
    res=content_df.iloc[indices[0]]['title']
    return res

# %%
search('Harry Potter')
# Out:
# 'Harry Potter and the Chamber of Secrets (Book 2)'

# %% [markdown]
# ### Utilisation d'un modèle BERT pré-entrainé

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import torch
import pickle

# %%
# !nvidia-smi
# Out:
# Tue Aug 19 13:56:29 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.97                 Driver Version: 580.97         CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060 ...  WDDM  |   00000000:01:00.0  On |                  N/A |
# | N/A   48C    P0             15W /  105W |     910MiB /   8188MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            1116    C+G   ...ef.win7x64\steamwebhelper.exe      N/A      |
# |    0   N/A  N/A            1972    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A            3108    C+G   ...cw5n1h2txyewy\WidgetBoard.exe      N/A      |
# |    0   N/A  N/A            3556    C+G   ...em32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A           12032    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           12108    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A           12440    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           12456    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           12588    C+G   ...t\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A           13228    C+G   ...IA app\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           13744    C+G   ...IA app\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           13956    C+G   ...l\Programs\Opera GX\opera.exe      N/A      |
# |    0   N/A  N/A           15148    C+G   ...0.3405.102\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           15904      C   ...s\Python\Python310\python.exe      N/A      |
# |    0   N/A  N/A           18268    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A           20956    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A           21348    C+G   ...ms\Microsoft VS Code\Code.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
print("GPU dispo :", torch.cuda.is_available())
print(f"Version: {torch.__version__}, GPU: {torch.cuda.is_available()}, NUM_GPU: {torch.cuda.device_count()}")
# Out:
# GPU dispo : True
# Version: 2.7.0+cu128, GPU: True, NUM_GPU: 1

# %%
sbert = SentenceTransformer('all-MiniLM-L6-v2', device='cuda' if torch.cuda.is_available() else 'cpu')

# %%
embeddings=sbert.encode(text_fusion_bert, batch_size=64, show_progress_bar=True) #avec dataset à 210k +
# Out:
# Batches:   0%|          | 0/906 [00:00<?, ?it/s]

# %%
sbert.save('../../models/sbert/')

# %%
with open('../../datasets/embeddings_sbert.pkl', 'wb') as f:
    pickle.dump(embeddings, f)

# %%
def affichage_reco_bert(reco):
    print(f"Recommandations pour : {content_df.iloc[index]['title']}\n")
    for title in reco: 
        print(title[0])

# %%
import ipywidgets as widgets
from IPython.display import display

book_input = widgets.Text(
    value = '',
    description = 'Book Title',
    disabled=False
)

book_list=widgets.Output()

def on_type(data):
    with book_list:
        book_list.clear_output()
        title = data["new"] 
        if len(title) > 1:
            display(recommend_books_by_embedding(title, embeddings, knn_bert, content_df))

book_input.observe(on_type, names='value')

display(book_input, book_list)
# Out:
# Text(value='', description='Book Title')
# Output()

# %% [markdown]
# ## TF-IDF + Word2Vec

# %%
import nltk
from gensim.models import Word2Vec
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

# === 2. Prétraitement ===
tokenized_docs = text_fusion.copy()

# %%
# === 3. Entraînement Word2Vec ===
w2v_tfidf = Word2Vec(sentences=tokenized_docs, vector_size=100, window=5, min_count=1, workers=4)

# %%
# === 4. TF-IDF ===
# Ici, on doit joiner les tokens pour TF-IDF
joined_docs = [" ".join(doc) for doc in tokenized_docs]
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(joined_docs)
tfidf_vocab = tfidf_vectorizer.vocabulary_

# %%
def tfidf_w2v_vector(doc_tokens, tfidf_row_sparse, model):
    vector_size = model.vector_size
    vec = np.zeros(vector_size)
    weight_sum = 0

    for word in doc_tokens:
        if word in model.wv and word in tfidf_vocab:
            tfidf_weight = tfidf_row_sparse[0, tfidf_vocab[word]]  # accès sparse
            vec += model.wv[word] * tfidf_weight
            weight_sum += tfidf_weight

    if weight_sum == 0:
        return vec  # vecteur nul
    else:
        return vec / weight_sum

# %%
fusion_token_tfidf = [
    tfidf_w2v_vector(tokenized_docs[i], tfidf_matrix[i], w2v_tfidf)
    for i in tqdm(range(len(tokenized_docs)))
]

# Stockage dans une Series
fusion_token_tfidf_serie = pd.Series(fusion_token_tfidf)
# Out:
# 100%|██████████| 57960/57960 [02:30<00:00, 385.09it/s]

# %%
X_tfidf=np.vstack(fusion_token_tfidf_serie)

# %%
with open('../../datasets/embeddings_tfidf_w2v.pkl', 'wb') as f:
    pickle.dump(X_tfidf, f)

# %% [markdown]
# ## Comparaison des recommandations des modèles

# %%
#chargement des emebeddings

with open('../../datasets/embeddings_w2v.pkl', 'rb') as f:
    X_w2v = pickle.load(f)

with open('../../datasets/embeddings_glove.pkl', 'rb') as f:
    X_glove = pickle.load(f)

with open('../../datasets/embeddings_sbert.pkl', 'rb') as f:
    embeddings = pickle.load(f)

with open('../../datasets/embeddings_tfidf_w2v.pkl', 'rb') as f:
    X_tfidf = pickle.load(f)

# %%
from sklearn.neighbors import NearestNeighbors
from joblib import dump, load
from sklearn.preprocessing import normalize

# Création des modèles KNN

knn_w2v = NearestNeighbors(n_neighbors=11, metric='cosine')
knn_glove = NearestNeighbors(n_neighbors=11, metric='cosine')
knn_sbert = NearestNeighbors(n_neighbors=11, metric='cosine')
knn_tfidf_w2v = NearestNeighbors(n_neighbors=11, metric='cosine')

# %%
# Entrainement des modèles

knn_w2v.fit(X_w2v)
knn_glove.fit(X_glove)
knn_sbert.fit(embeddings)
knn_tfidf_w2v.fit(X_tfidf)
# Out:
# NearestNeighbors(metric='cosine', n_neighbors=11)

# %%
# Choix du livre

book_index = np.where(content_df['title']=="Harry Potter and the Chamber of Secrets (Book 2)")[0][0]
book_title = content_df.iloc[book_index]['title']

book_index
# Out:
# 1327

# %%
def get_recommendations(knn_model, embeddings_matrix, book_index, top_k=10):
    distances, indices = knn_model.kneighbors([embeddings_matrix[book_index]])
    recs = []
    for i, idx in enumerate(indices[0][1:top_k+1]):  # On ignore le livre lui-même
        recs.append({
            #"rank": i+1,
            "title": content_df.iloc[idx]['title']
            #"ISBN": content_df.iloc[idx]['ISBN'],
            #"distance": distances[0][i+1],
            #"similarity": 1 - distances[0][i+1]
            #"idx": idx
        })
    return recs

# %%
# Récupérer les recommandations pour chaque modèle
recs_w2v = get_recommendations(knn_w2v, X_w2v, book_index)
recs_glove = get_recommendations(knn_glove, X_glove, book_index)
recs_sbert = get_recommendations(knn_sbert, embeddings, book_index)
recs_tfidf_w2v = get_recommendations(knn_tfidf_w2v, X_tfidf, book_index)

# %%
# Transformer en DataFrame pour comparaison
df_w2v = pd.DataFrame(recs_w2v).add_prefix("w2v_")
df_glove = pd.DataFrame(recs_glove).add_prefix("glove_")
df_sbert = pd.DataFrame(recs_sbert).add_prefix("sbert_")
df_tfidf_w2v = pd.DataFrame(recs_tfidf_w2v).add_prefix("tfidf_w2v_")

# %%
# Concaténer les résultats pour avoir un tableau comparatif
df_compare = pd.concat([df_w2v, df_glove, df_sbert, df_tfidf_w2v], axis=1)
print(f"Recommandations pour : {book_title}\n")
display(df_compare)
# Out:
# Recommandations pour : Harry Potter and the Chamber of Secrets (Book 2)
#                                            w2v_title  \
# 0  Harry Potter and the Prisoner of Azkaban (Book 3)
# 1  Ghosts Don't Eat Potato Chips (Adventures of t...
# 2  The Mystery of the Stolen Bike #8 (Marc Brown ...
# 3  The Mystery of the Homeless Treasure (The Home...
# 4  December Secrets (Kids of the Polk Street School)
# 5         Stage Invader (Wishbone Mysteries, No. 15)
# 6  GRADUATION (FINAL FRIENDS 3) : GRADUATION (Fin...
# 7               Down a Dark Hall (Laurel Leaf Books)
# 8  Dracula Doesn't Rock and Roll (Adventures of t...
# 9         The Return of the Third-Grade Ghosthunters
#
#                                          glove_title  \
# 0  Harry Potter and the Prisoner of Azkaban (Book 3)
# 1  The Sorcerer's Companion: A Guide to the Magic...
# 2  The Gospel According to Harry Potter: Spiritua...
# 3                          Support Your Local Wizard
# 4            Grave Peril (The Dresden Files, Book 3)
# 5                                    TOMORROWS MAGIC
# 6  The New Kid at School (Dragon Slayers' Academy...
# 7  The Books of Magic #1: The Invitation (The Boo...
# 8                         Last Term at Malory Towers
# 9   Harry Potter and the Bible: The Menace Behind...
#
#                                          sbert_title  \
# 0  Horrible Harry and the Dungeon (Puffin Chapter...
# 1  Harry Potter and the Prisoner of Azkaban (Book 3)
# 2     Danger In The Palace (Circle Of Magic, Book 4)
# 3           Horrible Harry's Secret (Horrible Harry)
# 4         Horrible Harry in Room 2B (A Young Puffin)
# 5  The Sorcerer's Companion: A Guide to the Magic...
# 6               The Classroom at the End of the Hall
# 7                Horrible Harry and the Ant Invasion
# 8                     Harry and the Terrible Whatzit
# 9                          Support Your Local Wizard
#
#                                      tfidf_w2v_title
# 0  Horrible Harry Moves Up to Third Grade (Puffin...
# 1           Horrible Harry's Secret (Horrible Harry)
# 2  Horrible Harry and the Dungeon (Puffin Chapter...
# 3   Horrible Harry Goes to the Moon (Horrible Harry)
# 4  The Gospel According to Harry Potter: Spiritua...
# 5                Horrible Harry and the Ant Invasion
# 6          Barry Trotter and the Unauthorized Parody
# 7  Harry Potter and the Sorcerer's Stone Movie Po...
# 8           Horrible Harry's Secret (Horrible Harry)
# 9         Horrible Harry in Room 2B (A Young Puffin)

# %% [markdown]
# # Recommandation Collaborative

# %%
collaborative_df = pd.read_csv('../../datasets/reco_datasets/collaborative_dataset_explicit.csv')

# %%
collaborative_df
# Out:
#        user_id        ISBN  rating
# 0          242  0553278223      10
# 1          243  0446364800       9
# 2          243  155874262X       5
# 3          243  0449006522       6
# 4          243  0446606383       6
# ...        ...         ...     ...
# 67400   278843  0060517794       7
# 67401   278843  0060173289       9
# 67402   278851  0894803700       5
# 67403   278851  1558531025       8
# 67404   278851  0440486599       5
#
# [67405 rows x 3 columns]

# %%
collaborative_df.shape
# Out:
# (67405, 3)

# %%
collaborative_df.duplicated(['user_id', 'ISBN']).sum()
# Out:
# 0

# %% [markdown]
# ## Matrice User-Book

# %%
from scipy.sparse import coo_matrix

# %%
collaborative_df['rating'] = pd.to_numeric(collaborative_df['rating'])

# %%
collaborative_df['user_index']=collaborative_df['user_id'].astype("category").cat.codes

# %%
collaborative_df['book_index']=collaborative_df['ISBN'].astype("category").cat.codes

# %%
collaborative_df.head()
# Out:
#    user_id        ISBN  rating  \
# 0   276725  034545104X       0
# 1   276726  0155061224       5
# 2   276727  0446520802       0
# 3   276729  052165615X       3
# 4   276729  0521795028       6
#
#                                                title  user_index  book_index
# 0                               Flesh Tones: A Novel       82917       39799
# 1                                   Rites of Passage       82918       19442
# 2                                       The Notebook       82919       73695
# 3                                     Help!: Level 1       82920       86750
# 4  The Amsterdam Connection : Level 4 (Cambridge ...       82920       86782

# %%
ratings_mat_coo=coo_matrix((collaborative_df['rating'], (collaborative_df['user_index'], collaborative_df['book_index'])))

# %%
ratings_mat_coo
# Out:
# <83602x216961 sparse matrix of type '<class 'numpy.int64'>'
# 	with 874985 stored elements in COOrdinate format>

# %%
ratings_mat=ratings_mat_coo.tocsr()

# %%
np.where(collaborative_df['user_index']==15488)
# Out:
# (array([166996, 166997, 166998, 166999, 167000, 167001, 167002, 167003,
#         167004, 167005, 167006, 167007, 167008, 167009, 167010, 167011,
#         167012, 167013, 167014, 167015, 167016, 167017, 167018, 167019,
#         167020, 167021, 167022, 167023, 167024, 167025, 167026, 167027,
#         167028, 167029, 167030, 167031, 167032, 167033, 167034, 167035,
#         167036, 167037, 167038, 167039, 167040, 167041, 167042, 167043,
#         167044, 167045, 167046, 167047, 167048, 167049, 167050, 167051,
#         167052, 167053, 167054, 167055, 167056, 167057, 167058, 167059,
#         167060, 167061, 167062, 167063, 167064, 167065, 167066, 167067,
#         167068, 167069, 167070, 167071, 167072, 167073, 167074, 167075,
#         167076, 167077, 167078, 167079, 167080, 167081, 167082, 167083,
#         167084, 167085, 167086, 167087, 167088, 167089, 167090, 167091,
#         167092, 167093], dtype=int64),)

# %%
index=15488

# %%
from sklearn.metrics.pairwise import cosine_similarity

sim = cosine_similarity(ratings_mat[index, :], ratings_mat).flatten()

# %%
indices = np.argpartition(sim, -15)[-15:]

indices
# Out:
# array([55104, 70102, 79323, 42415, 48700, 28284, 14836, 67843, 61288,
#        81010, 53494, 61646, 62281, 15488, 31848], dtype=int64)

# %%
similar_users = collaborative_df[collaborative_df['user_index'].isin(indices)].copy()

# %%
similar_users = similar_users[similar_users['user_id'] != 51742]

# %%
similar_users.head()
# Out:
#         user_id        ISBN  rating  \
# 161520    49587  0385490445       9
# 296071    94418  0385490445       9
# 337007   106369  0066621054       8
# 337008   106369  0449219364       9
# 337009   106369  0449219461       9
#
#                                                     title  user_index  \
# 161520                              Alias Grace : A Novel       14836
# 296071                              Alias Grace : A Novel       28284
# 337007             Longaberger: An American Success Story       31848
# 337008  G Is for Gumshoe (Kinsey Millhone Mysteries (P...       31848
# 337009  H Is for Homicide (Kinsey Millhone Mysteries (...       31848
#
#         book_index
# 161520       58655
# 296071       58655
# 337007       11146
# 337008       76106
# 337009       76111

# %%
book_recs=similar_users.groupby('ISBN').rating.agg(['count', 'mean'])

# %%
book_recs
# Out:
#             count       mean
# ISBN
# 0030018897      1   9.000000
# 0060504072      1  10.000000
# 0060928336      1   0.000000
# 0066621054      1   8.000000
# 0140502343      1  10.000000
# 0142001740      1   9.000000
# 015600125X      1   0.000000
# 0316693863      1   7.000000
# 0345308980      1   0.000000
# 0385319207      1   9.000000
# 0385490445      4   9.000000
# 0425175006      1   5.000000
# 0425179532      1   5.000000
# 0440127793      1   0.000000
# 0449219364      3   8.333333
# 0449219461      3   7.666667
# 0449221482      3   7.333333
# 0449221490      2   7.000000
# 0449221504      2   7.000000
# 0449221512      3   7.333333
# 0449911357      1  10.000000
# 0553260618      1   5.000000
# 0553271636      2   9.000000
# 0553279556      3   7.666667
# 0553279912      2   6.500000
# 0553280341      1   9.000000
# 0553280368      2   9.000000
# 0553284789      3   7.000000
# 0679731725      4   7.750000
# 0684813866      1   9.000000
# 0684826143      1   0.000000
# 0805013342      1   9.000000
# 0805059555      1   5.000000
# 1551666987      1   3.000000
# 1566198682      1   5.000000

# %% [markdown]
# ### Création de la matrice Livre-Utilisateur (et Utilisateur-Livre)

# %%
user_book_matrix_u=collaborative_df.pivot_table(index='user_id', columns='ISBN', values='rating') #pour faire une recommandation basée sur les utilisateurs

# %%
user_book_matrix_b=collaborative_df.pivot_table(index='title', columns='user_id', values='rating') #pour faire une recommandation basée sur les livres

# %%
user_book_matrix_u.head()
# Out:
# ISBN     0001010565  0001046438  0001047663  0001047868  000104799X  \
# user_id
# 254             NaN         NaN         NaN         NaN         NaN
# 2276            NaN         NaN         NaN         NaN         NaN
# 2766            NaN         NaN         NaN         NaN         NaN
# 2977            NaN         NaN         NaN         NaN         NaN
# 3363            NaN         NaN         NaN         NaN         NaN
#
# ISBN     0001048082  0001048473  0001049879  0001052039  0001053744  ...  \
# user_id                                                              ...
# 254             NaN         NaN         NaN         NaN         NaN  ...
# 2276            NaN         NaN         NaN         NaN         NaN  ...
# 2766            NaN         NaN         NaN         NaN         NaN  ...
# 2977            NaN         NaN         NaN         NaN         NaN  ...
# 3363            NaN         NaN         NaN         NaN         NaN  ...
#
# ISBN     999750805X  9997508769  9997511263  9997519086  9997522052  \
# user_id
# 254             NaN         NaN         NaN         NaN         NaN
# 2276            NaN         NaN         NaN         NaN         NaN
# 2766            NaN         NaN         NaN         NaN         NaN
# 2977            NaN         NaN         NaN         NaN         NaN
# 3363            NaN         NaN         NaN         NaN         NaN
#
# ISBN     9997542738  9998560802  9998914140  9999669972  9999984584
# user_id
# 254             NaN         NaN         NaN         NaN         NaN
# 2276            NaN         NaN         NaN         NaN         NaN
# 2766            NaN         NaN         NaN         NaN         NaN
# 2977            NaN         NaN         NaN         NaN         NaN
# 3363            NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 145592 columns]

# %%
user_book_matrix_b.head()
# Out:
# user_id                                             254     2276    2766    \
# title
# A Light in the Storm: The Civil War Diary of Am...     NaN     NaN     NaN
# Always Have Popsicles                                  NaN     NaN     NaN
# Apple Magic (The Collector's series)                   NaN     NaN     NaN
# Beyond IBM: Leadership Marketing and Finance fo...     NaN     NaN     NaN
# Clifford Visita El Hospital (Clifford El Gran P...     NaN     NaN     NaN
#
# user_id                                             2977    3363    3757    \
# title
# A Light in the Storm: The Civil War Diary of Am...     NaN     NaN     NaN
# Always Have Popsicles                                  NaN     NaN     NaN
# Apple Magic (The Collector's series)                   NaN     NaN     NaN
# Beyond IBM: Leadership Marketing and Finance fo...     NaN     NaN     NaN
# Clifford Visita El Hospital (Clifford El Gran P...     NaN     NaN     NaN
#
# user_id                                             4017    4385    6242    \
# title
# A Light in the Storm: The Civil War Diary of Am...     NaN     NaN     NaN
# Always Have Popsicles                                  NaN     NaN     NaN
# Apple Magic (The Collector's series)                   NaN     NaN     NaN
# Beyond IBM: Leadership Marketing and Finance fo...     NaN     NaN     NaN
# Clifford Visita El Hospital (Clifford El Gran P...     NaN     NaN     NaN
#
# user_id                                             6251    ...  274004  \
# title                                                       ...
# A Light in the Storm: The Civil War Diary of Am...     NaN  ...     NaN
# Always Have Popsicles                                  NaN  ...     NaN
# Apple Magic (The Collector's series)                   NaN  ...     NaN
# Beyond IBM: Leadership Marketing and Finance fo...     NaN  ...     NaN
# Clifford Visita El Hospital (Clifford El Gran P...     NaN  ...     NaN
#
# user_id                                             274061  274301  274308  \
# title
# A Light in the Storm: The Civil War Diary of Am...     NaN     NaN     NaN
# Always Have Popsicles                                  NaN     NaN     NaN
# Apple Magic (The Collector's series)                   NaN     NaN     NaN
# Beyond IBM: Leadership Marketing and Finance fo...     NaN     NaN     NaN
# Clifford Visita El Hospital (Clifford El Gran P...     NaN     NaN     NaN
#
# user_id                                             274808  275970  277427  \
# title
# A Light in the Storm: The Civil War Diary of Am...     NaN     NaN     NaN
# Always Have Popsicles                                  NaN     NaN     NaN
# Apple Magic (The Collector's series)                   NaN     NaN     NaN
# Beyond IBM: Leadership Marketing and Finance fo...     NaN     NaN     NaN
# Clifford Visita El Hospital (Clifford El Gran P...     NaN     NaN     NaN
#
# user_id                                             277478  277639  278418
# title
# A Light in the Storm: The Civil War Diary of Am...     NaN     NaN     NaN
# Always Have Popsicles                                  NaN     NaN     NaN
# Apple Magic (The Collector's series)                   NaN     NaN     NaN
# Beyond IBM: Leadership Marketing and Finance fo...     NaN     NaN     NaN
# Clifford Visita El Hospital (Clifford El Gran P...     NaN     NaN     NaN
#
# [5 rows x 899 columns]

# %%
user_book_matrix_u.fillna(0, inplace=True)

# %%
user_book_matrix_b.fillna(0, inplace=True)

# %%
user_book_matrix_u.shape
# Out:
# (899, 145592)

# %%
user_book_matrix_b.shape
# Out:
# (133737, 899)

# %%
matrix = user_book_matrix.loc[(user_book_matrix != 0).any(axis=1), (user_book_matrix != 0).any(axis=0)]

# %%
matrix
# Out:
# user_id                                             254     2276    2766    \
# title
#  A Light in the Storm: The Civil War Diary of A...     0.0     0.0     0.0
#  Dark Justice                                          0.0     0.0     0.0
#  Earth Prayers From around the World: 365 Praye...     0.0     0.0     0.0
#  Final Fantasy Anthology: Official Strategy Gui...     0.0     0.0     0.0
#  God's Little Promise Book                             0.0     0.0     0.0
# ...                                                    ...     ...     ...
# them (Modern Library)                                  0.0     0.0     0.0
# why I'm like this : True Stories                       0.0     0.0     0.0
# Â¡Corre, perro, corre!                                 0.0     0.0     0.0
# Â¿Eres tu mi mamÃ¡?/Are You My Mother?                 0.0     0.0     0.0
# Ã?ngeles fugaces (Falling Angels)                      0.0     0.0     0.0
#
# user_id                                             2977    3363    3757    \
# title
#  A Light in the Storm: The Civil War Diary of A...     0.0     0.0     0.0
#  Dark Justice                                          0.0     0.0     0.0
#  Earth Prayers From around the World: 365 Praye...     0.0     0.0     0.0
#  Final Fantasy Anthology: Official Strategy Gui...     0.0     0.0     0.0
#  God's Little Promise Book                             0.0     0.0     0.0
# ...                                                    ...     ...     ...
# them (Modern Library)                                  0.0     0.0     0.0
# why I'm like this : True Stories                       0.0     0.0     0.0
# Â¡Corre, perro, corre!                                 0.0     0.0     0.0
# Â¿Eres tu mi mamÃ¡?/Are You My Mother?                 0.0     0.0     0.0
# Ã?ngeles fugaces (Falling Angels)                      0.0     0.0     0.0
#
# user_id                                             4017    4385    6242    \
# title
#  A Light in the Storm: The Civil War Diary of A...     0.0     0.0     0.0
#  Dark Justice                                          0.0     0.0     0.0
#  Earth Prayers From around the World: 365 Praye...     0.0     0.0     0.0
#  Final Fantasy Anthology: Official Strategy Gui...     0.0     0.0     0.0
#  God's Little Promise Book                             0.0     0.0     0.0
# ...                                                    ...     ...     ...
# them (Modern Library)                                  0.0     0.0     0.0
# why I'm like this : True Stories                       0.0     0.0     0.0
# Â¡Corre, perro, corre!                                 0.0     0.0     0.0
# Â¿Eres tu mi mamÃ¡?/Are You My Mother?                 0.0     0.0     0.0
# Ã?ngeles fugaces (Falling Angels)                      0.0     0.0     0.0
#
# user_id                                             6251    ...  274004  \
# title                                                       ...
#  A Light in the Storm: The Civil War Diary of A...     0.0  ...     0.0
#  Dark Justice                                          0.0  ...     0.0
#  Earth Prayers From around the World: 365 Praye...     0.0  ...     0.0
#  Final Fantasy Anthology: Official Strategy Gui...     0.0  ...     0.0
#  God's Little Promise Book                             0.0  ...     0.0
# ...                                                    ...  ...     ...
# them (Modern Library)                                  0.0  ...     0.0
# why I'm like this : True Stories                       0.0  ...     0.0
# Â¡Corre, perro, corre!                                 0.0  ...     0.0
# Â¿Eres tu mi mamÃ¡?/Are You My Mother?                 0.0  ...     0.0
# Ã?ngeles fugaces (Falling Angels)                      0.0  ...     0.0
#
# user_id                                             274061  274301  274308  \
# title
#  A Light in the Storm: The Civil War Diary of A...     0.0     0.0     0.0
#  Dark Justice                                          0.0     0.0     0.0
#  Earth Prayers From around the World: 365 Praye...     0.0     0.0     0.0
#  Final Fantasy Anthology: Official Strategy Gui...     0.0     0.0     0.0
#  God's Little Promise Book                             0.0     0.0     0.0
# ...                                                    ...     ...     ...
# them (Modern Library)                                  0.0     0.0     0.0
# why I'm like this : True Stories                       0.0     0.0     0.0
# Â¡Corre, perro, corre!                                 0.0     0.0     0.0
# Â¿Eres tu mi mamÃ¡?/Are You My Mother?                 0.0     0.0     0.0
# Ã?ngeles fugaces (Falling Angels)                      0.0     0.0     0.0
#
# user_id                                             274808  275970  277427  \
# title
#  A Light in the Storm: The Civil War Diary of A...     0.0     0.0     0.0
#  Dark Justice                                          0.0     0.0     0.0
#  Earth Prayers From around the World: 365 Praye...     0.0     0.0     0.0
#  Final Fantasy Anthology: Official Strategy Gui...     0.0     0.0     0.0
#  God's Little Promise Book                             0.0     0.0     0.0
# ...                                                    ...     ...     ...
# them (Modern Library)                                  0.0     0.0     0.0
# why I'm like this : True Stories                       0.0     0.0     0.0
# Â¡Corre, perro, corre!                                 0.0     0.0     0.0
# Â¿Eres tu mi mamÃ¡?/Are You My Mother?                 0.0     0.0     0.0
# Ã?ngeles fugaces (Falling Angels)                      0.0     0.0     0.0
#
# user_id                                             277478  277639  278418
# title
#  A Light in the Storm: The Civil War Diary of A...     0.0     0.0     0.0
#  Dark Justice                                          0.0     0.0     0.0
#  Earth Prayers From around the World: 365 Praye...     0.0     0.0     0.0
#  Final Fantasy Anthology: Official Strategy Gui...     0.0     0.0     0.0
#  God's Little Promise Book                             0.0     0.0     0.0
# ...                                                    ...     ...     ...
# them (Modern Library)                                  0.0     0.0     0.0
# why I'm like this : True Stories                       0.0     0.0     0.0
# Â¡Corre, perro, corre!                                 0.0     0.0     0.0
# Â¿Eres tu mi mamÃ¡?/Are You My Mother?                 0.0     0.0     0.0
# Ã?ngeles fugaces (Falling Angels)                      0.0     0.0     0.0
#
# [57122 rows x 890 columns]

# %% [markdown]
# ### Sparsing

# %%
from scipy.sparse import csr_matrix

# %%
user_book_sparse=csr_matrix(user_book_matrix_b)

# %%
user_book_sparse
# Out:
# <133737x899 sparse matrix of type '<class 'numpy.float64'>'
# 	with 103377 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Utilisation de KNN

# %%
from sklearn.neighbors import NearestNeighbors
from joblib import dump, load

# %%
knn_collab=NearestNeighbors(algorithm='brute')

# %%
knn_collab.fit(user_book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
dump(knn_collab, './models/knn_model_collab.joblib')
# Out:
# ['./models/knn_model_collab.joblib']

# %%
book_names=user_book_matrix_b.index

# %%
book_names[:10]
# Out:
# Index([' A Light in the Storm: The Civil War Diary of Amelia Martin, Fenwick Island, Delaware, 1861 (Dear America)',
#        ' Always Have Popsicles', ' Apple Magic (The Collector's series)',
#        ' Beyond IBM: Leadership Marketing and Finance for the 1990s',
#        ' Clifford Visita El Hospital (Clifford El Gran Perro Colorado)',
#        ' Dark Justice', ' Deceived',
#        ' Earth Prayers From around the World: 365 Prayers, Poems, and Invocations for Honoring the Earth',
#        ' Final Fantasy Anthology: Official Strategy Guide (Brady Games)',
#        ' God's Little Promise Book'],
#       dtype='object', name='title')

# %%
np.where(book_names=='Harry Potter and the Chamber of Secrets')
# Out:
# (array([43745], dtype=int64),)

# %%
index=43747

# %%
user_book_matrix_b.iloc[index, :]
# Out:
# user_id
# 254       9.0
# 2276      0.0
# 2766      0.0
# 2977      0.0
# 3363      0.0
#          ...
# 275970    9.0
# 277427    0.0
# 277478    0.0
# 277639    0.0
# 278418    0.0
# Name: Harry Potter and the Chamber of Secrets (Book 2), Length: 899, dtype: float64

# %%
distances, reco = knn_collab.kneighbors(user_book_matrix_b.iloc[index, :].values.reshape(1, -1), n_neighbors=6)

# %%
distances
# Out:
# array([[ 0.        , 67.73129098, 69.57210488, 72.22091879, 74.67224682,
#         75.03073444]])

# %%
reco[0]
# Out:
# array([ 43747,  43759,  43752,  43763, 114542,  98769], dtype=int64)

# %%
for i in reco[0]:
    print(user_book_matrix_b.index[i])
# Out:
# Harry Potter and the Chamber of Secrets (Book 2)
# Harry Potter and the Prisoner of Azkaban (Book 3)
# Harry Potter and the Goblet of Fire (Book 4)
# Harry Potter and the Sorcerer's Stone (Book 1)
# The Secret of the Indian (Indian in the Cupboard)
# The Canterbury Tales (Bantam Classics)

# %% [markdown]
# ## Utilisation de SVD (via Surprise)

# %%
collaborative_df_explicit = pd.read_csv('../../datasets/reco_datasets/collaborative_dataset_explicit.csv')

# %%
reader = Reader(rating_scale=(1, 10))
data = Dataset.load_from_df(collaborative_df_explicit[['user_id', 'ISBN', 'rating']], reader)

# %% [markdown]
# ### GridSearch et RandomSearch pour sélection d'hyper-paramètres

# %%
param_grid = {
    'n_factors': [20, 50, 75, 125, 150, 225],
    'lr_all': [0.0005, 0.001, 0.002, 0.005],
    'reg_all': [0.005, 0.01, 0.015, 0.02, 0.03, 0.05],
    'n_epochs': [10, 20, 30, 50, 70, 100]
}

# %%
rs = RandomizedSearchCV(algo_class=SVD, param_distributions=param_grid, cv=10)

# %%
rs.fit(data)

# %%
gs = GridSearchCV(algo_class=SVD, param_grid=param_grid, cv=5, n_jobs=-1, joblib_verbose=1)

# %%
gs.fit(data)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   28.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 784 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 1234 tasks      | elapsed: 19.7min
# [Parallel(n_jobs=-1)]: Done 1784 tasks      | elapsed: 32.0min
# [Parallel(n_jobs=-1)]: Done 2434 tasks      | elapsed: 49.9min
# [Parallel(n_jobs=-1)]: Done 3184 tasks      | elapsed: 74.8min
# [Parallel(n_jobs=-1)]: Done 4034 tasks      | elapsed: 109.3min
# [Parallel(n_jobs=-1)]: Done 4320 out of 4320 | elapsed: 123.1min finished

# %%
print("Meilleurs hyperparamètres (RMSE) :", gs.best_params['rmse'])
print("Score RMSE moyen :", gs.best_score['rmse'])
print("Score MAE moyen :", gs.best_score['mae'])
# Out:
# Meilleurs hyperparamètres (RMSE) : {'n_factors': 20, 'lr_all': 0.002, 'reg_all': 0.05, 'n_epochs': 50}
# Score RMSE moyen : 1.5746239454070294
# Score MAE moyen : 1.2100412026701315

# %%
summary_df = pd.DataFrame({'Model': 'SVD',
                           'RMSE': gs.best_score['rmse'],
                           'Model Configuration':[f'{gs.best_params["rmse"]}']})

# %%
summary_df.to_csv('./param/best_svd_params.csv', index=False)

# %% [markdown]
# ### Utilisation de SVD avec les meilleurs paramètres

# %%
best_params_df=pd.read_csv('../../param/best_svd_params.csv')

# %%
best_params_df
# Out:
#   Model      RMSE                                Model Configuration
# 0   SVD  1.574624  {'n_factors': 20, 'lr_all': 0.002, 'reg_all': ...

# %%
best_params_df['Model Configuration'][0]
# Out:
# "{'n_factors': 20, 'lr_all': 0.002, 'reg_all': 0.05, 'n_epochs': 50}"

# %%
trainset, testset = train_test_split(data, test_size=0.2)

# %%
svd = SVD(n_factors=20, lr_all=0.002, reg_all=0.05, n_epochs=50)

# %%
svd.fit(trainset)

# %%
predictions = svd.test(testset)

# %%
rmse = accuracy.rmse(predictions)
# Out:
# RMSE: 1.5415

# %%
full_data = data.build_full_trainset()

# %%
svd.fit(full_data)

# %%
dump.dump('../../models/svd/svd_model_best', algo=svd)

# %% [markdown]
# ### Prédictions avec SVD

# %%
# %load_ext autoreload
# %autoreload 2

from package.reco_collab_initial import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Recommandation aléatoire d'un livre que l'utilisateur n'a pas noté

recommandation_collaborative(2, svd, collaborative_df_explicit, books)
# Out:
# 'Thinner'

# %%
user=32773

# %%
ids = set(collaborative_df_explicit['user_id'])
ids
# Out:
# {32773,
#  262151,
#  163851,
#  65549,
#  196621,
#  98322,
#  262169,
#  131099,
#  229409,
#  32802,
#  163876,
#  98344,
#  262186,
#  65584,
#  196656,
#  98356,
#  131126,
#  262208,
#  131154,
#  98391,
#  98428,
#  229502,
#  65663,
#  65665,
#  196738,
#  163973,
#  98440,
#  131238,
#  196775,
#  262311,
#  65710,
#  229551,
#  98484,
#  164027,
#  32964,
#  164036,
#  196821,
#  65752,
#  164061,
#  65769,
#  33004,
#  242,
#  243,
#  98547,
#  131317,
#  262391,
#  254,
#  65791,
#  164096,
#  229632,
#  33026,
#  262399,
#  262407,
#  98575,
#  229656,
#  196891,
#  131363,
#  229681,
#  262459,
#  196930,
#  98628,
#  229703,
#  131402,
#  229707,
#  65877,
#  98647,
#  33114,
#  98655,
#  33124,
#  229741,
#  229742,
#  131441,
#  65913,
#  98686,
#  388,
#  197000,
#  229768,
#  262541,
#  131476,
#  197012,
#  65946,
#  33179,
#  98722,
#  98723,
#  33200,
#  98741,
#  131510,
#  229816,
#  446,
#  98758,
#  98783,
#  98787,
#  164323,
#  262634,
#  503,
#  505,
#  507,
#  33283,
#  131594,
#  262666,
#  66073,
#  33307,
#  131622,
#  33319,
#  164418,
#  98887,
#  66129,
#  197206,
#  98904,
#  131675,
#  131686,
#  164465,
#  98930,
#  230013,
#  638,
#  98943,
#  33408,
#  164480,
#  643,
#  651,
#  164492,
#  230030,
#  98988,
#  197293,
#  164533,
#  99001,
#  33474,
#  709,
#  164549,
#  99026,
#  33491,
#  99032,
#  735,
#  230115,
#  164581,
#  164584,
#  33517,
#  197364,
#  262902,
#  131837,
#  131855,
#  66323,
#  262940,
#  99102,
#  197410,
#  230180,
#  805,
#  33580,
#  197424,
#  262974,
#  164675,
#  99146,
#  66387,
#  262998,
#  230249,
#  882,
#  164728,
#  197502,
#  900,
#  901,
#  66443,
#  230293,
#  99222,
#  99227,
#  929,
#  99242,
#  66483,
#  66485,
#  263107,
#  66518,
#  164828,
#  230374,
#  99312,
#  99313,
#  99314,
#  132083,
#  263163,
#  66556,
#  230400,
#  1025,
#  164870,
#  230411,
#  66574,
#  99347,
#  33816,
#  33818,
#  197659,
#  230427,
#  33826,
#  263219,
#  197687,
#  164926,
#  33862,
#  132171,
#  132173,
#  66640,
#  132188,
#  33888,
#  230496,
#  132199,
#  1131,
#  132203,
#  99441,
#  66680,
#  230522,
#  1155,
#  33933,
#  197775,
#  33943,
#  263321,
#  263323,
#  263325,
#  33958,
#  263344,
#  33974,
#  132282,
#  1211,
#  263357,
#  99523,
#  230599,
#  66765,
#  33999,
#  165073,
#  263383,
#  1248,
#  66789,
#  230629,
#  197866,
#  66797,
#  263413,
#  132371,
#  263445,
#  132375,
#  197913,
#  66842,
#  34075,
#  230687,
#  263460,
#  34087,
#  132392,
#  230699,
#  99630,
#  230708,
#  66878,
#  165183,
#  34115,
#  34152,
#  263534,
#  165232,
#  198011,
#  198012,
#  66942,
#  99720,
#  263560,
#  132492,
#  165262,
#  1424,
#  165268,
#  99738,
#  1435,
#  198046,
#  34215,
#  132522,
#  263601,
#  132531,
#  165308,
#  165319,
#  263637,
#  132572,
#  263645,
#  165345,
#  132582,
#  263663,
#  34300,
#  67079,
#  1548,
#  67085,
#  165392,
#  198177,
#  67111,
#  165420,
#  1585,
#  263733,
#  132663,
#  198213,
#  34377,
#  132684,
#  230997,
#  198243,
#  67174,
#  99946,
#  132716,
#  99955,
#  165499,
#  67198,
#  165503,
#  165507,
#  1674,
#  165516,
#  99996,
#  263842,
#  100009,
#  231081,
#  132786,
#  1733,
#  67270,
#  263877,
#  165582,
#  198355,
#  67288,
#  34526,
#  67296,
#  100066,
#  132836,
#  132846,
#  132851,
#  100088,
#  100119,
#  67354,
#  34588,
#  34597,
#  132901,
#  165669,
#  34600,
#  231210,
#  132909,
#  1848,
#  132930,
#  231237,
#  231241,
#  67402,
#  67403,
#  34636,
#  198483,
#  67415,
#  231255,
#  231263,
#  165728,
#  231264,
#  264031,
#  1903,
#  165758,
#  165759,
#  100227,
#  264082,
#  198547,
#  264085,
#  100251,
#  100264,
#  231337,
#  133034,
#  231340,
#  165806,
#  231351,
#  231354,
#  67515,
#  34752,
#  231374,
#  67542,
#  264152,
#  2010,
#  67547,
#  2012,
#  231393,
#  165866,
#  2030,
#  2033,
#  34801,
#  2041,
#  165884,
#  67591,
#  100361,
#  198692,
#  231462,
#  100393,
#  67627,
#  133166,
#  34864,
#  2103,
#  198711,
#  2110,
#  198726,
#  133192,
#  67663,
#  264284,
#  67677,
#  198755,
#  100454,
#  133225,
#  100459,
#  67694,
#  198767,
#  34932,
#  264311,
#  198781,
#  264317,
#  166017,
#  264321,
#  2179,
#  133258,
#  133272,
#  264355,
#  133284,
#  100519,
#  34987,
#  133296,
#  231613,
#  67785,
#  35030,
#  100578,
#  2276,
#  133348,
#  35050,
#  166123,
#  2288,
#  100594,
#  166141,
#  67838,
#  67840,
#  2313,
#  264464,
#  198930,
#  2337,
#  100644,
#  100648,
#  133416,
#  133418,
#  2358,
#  2363,
#  67910,
#  198982,
#  35148,
#  264525,
#  67930,
#  264543,
#  199016,
#  264555,
#  199025,
#  35188,
#  67958,
#  199041,
#  231827,
#  68000,
#  35233,
#  100782,
#  231857,
#  199092,
#  199095,
#  264634,
#  264637,
#  133567,
#  133571,
#  100815,
#  264657,
#  231891,
#  231897,
#  100846,
#  264688,
#  166391,
#  35320,
#  199167,
#  166409,
#  199178,
#  199180,
#  133654,
#  68128,
#  199209,
#  100906,
#  133689,
#  231993,
#  68156,
#  133706,
#  35407,
#  68185,
#  166492,
#  100964,
#  35433,
#  133738,
#  133747,
#  232052,
#  35445,
#  100984,
#  264828,
#  232067,
#  68249,
#  35486,
#  2719,
#  68256,
#  264862,
#  35490,
#  264863,
#  166569,
#  232106,
#  101035,
#  232109,
#  232131,
#  166596,
#  2766,
#  101081,
#  101091,
#  2793,
#  2799,
#  264947,
#  166646,
#  199416,
#  232211,
#  101141,
#  68383,
#  264996,
#  133935,
#  133957,
#  2891,
#  101196,
#  232271,
#  68436,
#  101209,
#  199515,
#  101214,
#  265075,
#  134005,
#  35704,
#  101242,
#  35707,
#  265083,
#  35718,
#  2954,
#  68491,
#  265115,
#  2977,
#  166824,
#  166825,
#  166828,
#  166830,
#  101304,
#  101305,
#  68555,
#  35793,
#  68568,
#  101336,
#  68581,
#  134118,
#  265205,
#  134137,
#  35836,
#  265221,
#  166922,
#  35857,
#  35859,
#  232492,
#  265276,
#  3145,
#  232522,
#  35918,
#  35921,
#  35931,
#  199772,
#  3167,
#  265313,
#  134247,
#  134264,
#  232579,
#  134278,
#  167052,
#  101517,
#  68760,
#  68768,
#  36003,
#  232611,
#  134311,
#  265383,
#  101550,
#  265403,
#  199871,
#  36043,
#  134347,
#  3282,
#  101606,
#  68846,
#  101614,
#  101620,
#  167166,
#  3329,
#  3331,
#  134403,
#  265487,
#  3346,
#  167189,
#  68886,
#  68887,
#  265504,
#  134434,
#  3363,
#  36135,
#  3371,
#  3373,
#  232756,
#  36157,
#  101696,
#  101699,
#  134467,
#  200009,
#  167243,
#  68943,
#  265553,
#  134483,
#  101731,
#  134508,
#  101741,
#  265591,
#  68984,
#  232838,
#  265607,
#  265620,
#  134556,
#  69023,
#  36256,
#  167327,
#  69042,
#  167349,
#  265656,
#  134596,
#  69063,
#  36299,
#  69076,
#  69078,
#  101851,
#  134621,
#  69089,
#  3556,
#  36326,
#  36327,
#  134641,
#  232945,
#  101876,
#  3578,
#  232959,
#  200196,
#  232964,
#  3594,
#  200206,
#  265751,
#  232990,
#  200226,
#  69156,
#  167471,
#  200245,
#  167478,
#  3640,
#  200248,
#  265784,
#  69188,
#  167494,
#  233041,
#  167507,
#  3675,
#  69211,
#  167517,
#  167521,
#  134761,
#  3693,
#  69232,
#  200315,
#  134784,
#  200323,
#  69252,
#  167556,
#  3719,
#  167562,
#  102029,
#  134797,
#  233117,
#  265889,
#  167587,
#  134837,
#  167611,
#  167614,
#  265918,
#  167625,
#  36554,
#  134863,
#  200402,
#  200408,
#  200422,
#  69355,
#  3827,
#  265972,
#  36606,
#  167678,
#  3840,
#  36609,
#  69378,
#  102154,
#  69389,
#  102164,
#  69405,
#  134948,
#  233256,
#  167722,
#  102189,
#  36673,
#  167746,
#  266056,
#  102220,
#  3917,
#  167761,
#  3923,
#  167782,
#  36715,
#  200556,
#  200557,
#  167800,
#  200568,
#  102275,
#  135043,
#  36741,
#  135045,
#  167812,
#  167813,
#  200585,
#  36749,
#  135061,
#  167844,
#  4017,
#  69554,
#  266164,
#  200643,
#  36807,
#  36817,
#  233430,
#  102359,
#  233431,
#  200674,
#  36836,
#  233445,
#  36839,
#  102375,
#  135149,
#  266226,
#  266229,
#  4092,
#  102399,
#  135170,
#  266268,
#  4131,
#  36907,
#  266283,
#  69684,
#  233526,
#  135228,
#  4157,
#  69697,
#  200772,
#  36935,
#  233543,
#  266312,
#  36938,
#  69709,
#  69721,
#  266331,
#  135265,
#  168034,
#  168036,
#  4197,
#  102505,
#  233578,
#  135277,
#  168047,
#  36978,
#  266355,
#  69749,
#  4221,
#  4223,
#  168064,
#  69775,
#  102564,
#  37030,
#  102571,
#  69808,
#  135351,
#  135360,
#  168129,
#  135367,
#  135376,
#  168144,
#  266466,
#  4334,
#  233711,
#  266478,
#  102642,
#  135411,
#  102647,
#  233731,
#  233738,
#  200978,
#  233747,
#  102676,
#  168212,
#  168216,
#  266522,
#  4385,
#  135458,
#  200993,
#  69933,
#  102702,
#  37168,
#  102705,
#  168245,
#  201017,
#  102719,
#  69955,
#  201036,
#  69967,
#  201042,
#  69971,
#  37208,
#  201058,
#  37227,
#  37235,
#  102772,
#  168307,
#  37239,
#  70014,
#  233856,
#  168336,
#  266650,
#  233889,
#  70052,
#  201128,
#  37293,
#  233903,
#  70065,
#  201141,
#  266678,
#  233911,
#  135609,
#  102844,
#  233917,
#  37310,
#  37311,
#  168387,
#  168388,
#  135653,
#  4600,
#  135673,
#  233976,
#  135681,
#  266753,
#  4622,
#  168464,
#  135703,
#  37400,
#  102939,
#  102945,
#  70183,
#  234023,
#  70192,
#  102967,
#  135736,
#  266807,
#  37447,
#  135753,
#  201290,
#  70222,
#  135768,
#  266840,
#  266842,
#  70238,
#  135776,
#  201323,
#  266865,
#  266866,
#  37493,
#  37512,
#  37527,
#  135831,
#  70302,
#  37538,
#  70318,
#  4785,
#  37556,
#  234165,
#  4795,
#  266940,
#  135869,
#  37567,
#  135873,
#  168642,
#  37573,
#  135895,
#  37597,
#  234205,
#  201447,
#  103144,
#  70379,
#  37623,
#  70401,
#  70402,
#  201475,
#  37644,
#  70415,
#  267033,
#  4896,
#  168736,
#  135975,
#  234281,
#  234286,
#  234288,
#  267061,
#  201526,
#  4938,
#  136010,
#  201548,
#  37712,
#  201557,
#  136037,
#  168816,
#  234359,
#  136062,
#  136071,
#  103304,
#  70541,
#  103315,
#  37790,
#  234399,
#  103336,
#  136104,
#  201641,
#  5037,
#  267184,
#  70585,
#  70594,
#  201674,
#  136139,
#  201677,
#  201684,
#  201697,
#  70628,
#  267249,
#  37874,
#  267256,
#  70649,
#  168954,
#  136193,
#  70666,
#  168971,
#  136205,
#  37905,
#  267282,
#  103445,
#  168985,
#  201763,
#  201768,
#  37929,
#  136237,
#  169006,
#  70703,
#  136240,
#  201776,
#  201783,
#  136252,
#  37950,
#  136255,
#  201792,
#  267326,
#  234565,
#  37968,
#  70740,
#  37974,
#  5209,
#  169054,
#  169057,
#  136291,
#  37989,
#  234597,
#  103541,
#  234614,
#  136313,
#  234623,
#  136326,
#  38023,
#  38034,
#  136348,
#  234657,
#  234672,
#  234675,
#  267444,
#  234683,
#  234685,
#  136382,
#  267453,
#  201923,
#  103624,
#  70864,
#  5331,
#  5333,
#  234721,
#  5350,
#  103656,
#  169192,
#  136430,
#  ...}

# %%
# Top k recommandations à un utilisateur

recommandation_collaborative_top_k(5, 32773, svd, collaborative_df_explicit, books, ids)
# Out:
#       user_id        ISBN  note_predite  \
# 2669    32773  0836213319      9.334601
# 2545    32773  0439425220      9.306763
# 341     32773  0743454529      9.289037
# 575     32773  0618002235      9.189893
# 2092    32773  0345339738      9.174055
#
#                                                   title
# 2669                       Dilbert: A Book of Postcards
# 2545  Harry Potter and the Chamber of Secrets Postca...
# 341        My Sister's Keeper : A Novel (Picoult, Jodi)
# 575      The Two Towers (The Lord of the Rings, Part 2)
# 2092  The Return of the King (The Lord of the Rings,...

# %%
predicted_ratings=predict_unrated_books(user, svd, get_unrated_item(user, collaborative_df_explicit))

# %%
predicted_ratings
# Out:
#       user_id        ISBN  note_predite
# 2669    32773  0836213319      9.334601
# 2545    32773  0439425220      9.306763
# 341     32773  0743454529      9.289037
# 575     32773  0618002235      9.189893
# 2092    32773  0345339738      9.174055
# ...       ...         ...           ...
# 2116    32773  0802139868      5.977992
# 1781    32773  039914739X      5.906538
# 443     32773  0441359175      5.890505
# 2185    32773  0425182908      5.723018
# 147     32773  0971880107      3.988986
#
# [2833 rows x 3 columns]

# %% [markdown]
# ## Utilisation de NMF (via Surprise)

# %%
reader = Reader(rating_scale=(1, 10))
data = Dataset.load_from_df(collaborative_df_explicit[['user_id', 'ISBN', 'rating']], reader)

# %%
trainset, testset = train_test_split(data, test_size=0.2)

# %%
nmf_surprise=NMF(n_factors=20)
nmf_surprise.fit(trainset)

# %%
predictions = nmf_surprise.test(testset)
rmse = accuracy.rmse(predictions)
# Out:
# RMSE: 2.2408

# %%
param_grid_gs_nmf = {
    'n_factors': [20, 50, 70, 100, 125],
    'n_epochs': [10, 20, 30, 50, 100],
    'reg_pu':[0.02, 0.04, 0.06, 0.08, 0.1],
    'reg_qi':[0.02, 0.04, 0.06, 0.08, 0.1]
}
gs_nmf = GridSearchCV(algo_class=NMF, param_grid=param_grid_gs_nmf, cv=3, n_jobs=-1, joblib_verbose=1)

# %%
gs_nmf.fit(data)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:   55.7s
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:  3.9min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 gs_nmf.fit(data)
#
# File c:\Users\tarek\AppData\Local\Programs\Python\Python310\lib\site-packages\surprise\model_selection\search.py:104, in BaseSearchCV.fit(self, data)
#      90 cv = get_cv(self.cv)
#      92 delayed_list = (
#      93     delayed(fit_and_score)(
#      94         self.algo_class(**params),
#    (...)
#     102     )
#     103 )
# --> 104 out = Parallel(
#     105     n_jobs=self.n_jobs,
#     106     pre_dispatch=self.pre_dispatch,
#     107     verbose=self.joblib_verbose,
#     108 )(delayed_list)
#     110 (test_measures_dicts, train_measures_dicts, fit_times, test_times) = zip(*out)
#     112 # test_measures_dicts is a list of dict like this:
#     113 # [{'mae': 1, 'rmse': 2}, {'mae': 2, 'rmse': 3} ...]
#     114 # E.g. for 5 splits, the first 5 dicts are for the first param
#    (...)
#     121 # (n_parameters_combinations, n_splits). This way we can easily compute
#     122 # the mean and std dev over all splits or over all param comb.
#
# File c:\Users\tarek\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File c:\Users\tarek\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File c:\Users\tarek\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:1800, in Parallel._retrieve(self)
#    1789 if self.return_ordered:
#    1790     # Case ordered: wait for completion (or error) of the next job
#    1791     # that have been dispatched and not retrieved yet. If no job
#    (...)
#    1795     # control only have to be done on the amount of time the next
#    1796     # dispatched job is pending.
#    1797     if (nb_jobs == 0) or (
#    1798         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799     ):
# -> 1800         time.sleep(0.01)
#    1801         continue
#    1803 elif nb_jobs == 0:
#    1804     # Case unordered: jobs are added to the list of jobs to
#    1805     # retrieve `self._jobs` only once completed or in error, which
#    (...)
#    1811     # timeouts before any other dispatched job has completed and
#    1812     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:

# %%
# Meilleurs paramètres trouvés
print("Meilleurs hyperparamètres (RMSE) :", gs_nmf.best_params['rmse'])
print("Score RMSE moyen :", gs_nmf.best_score['rmse'])
print("Score MAE moyen :", gs_nmf.best_score['mae'])

# %%
nmf_surprise=NMF(n_factors=125, n_epochs=50)
full_data=data.build_full_trainset
nmf_surprise.fit(trainset)

# %%
recommandation_collaborative_top_k(5, user, nmf_surprise, collaborative_df_explicit, books)
# Out:
#          ISBN                              title             author  year  \
# 0  0345450736  Between Sisters (Hannah, Kristin)     KRISTIN HANNAH  2003
# 1  0006375952                     City of Djinns  William Dalrymple  1994
# 2  031226481X              We Love Harry Potter!       Sharon Moore  1999
# 3  0380721457                      Mrs. Dewinter    Susan Hill Long  1994
# 4  0671552473     Him With His Foot in His Mouth        Saul Bellow  1985
#
#             publisher
# 0    Ballantine Books
# 1       Harpercollins
# 2  St. Martin's Press
# 3                Avon
# 4              Pocket

# %%
ids = collaborative_df_explicit['user_id'].unique()

# %% [markdown]
# ## Comparaison entre SVD et NMF

# %%
reader = Reader(rating_scale=(1, 10))
data = Dataset.load_from_df(collaborative_df_explicit[['user_id', 'ISBN', 'rating']], reader)

# %%
collaborative_df_explicit.shape
# Out:
# (197413, 4)

# %%
svd = SVD(n_factors=100, n_epochs=50) 
nmf_surprise=NMF(n_factors=100, n_epochs=50)

# %%
trainset, testset = train_test_split(data, test_size=0.3)

# %%
nmf_surprise.fit(trainset)
svd.fit(trainset)

# %%
pred_svd = svd.test(testset)
pred_nmf = nmf_surprise.test(testset)

# %%
print('RMSE (SVD) : ', accuracy.rmse(pred_svd))
print('RMSE (NMF) : ', accuracy.rmse(pred_nmf))
# Out:
# RMSE: 1.6171
# RMSE (SVD) :  1.617071498768352
# RMSE: 2.4342
# RMSE (NMF) :  2.4341947271774353

# %% [markdown]
# Avec les mêmes paramètres, le RMSE de NMF est plus grand d'environ 1 par rapport à SVD.

# %%
full_data=data.build_full_trainset()

nmf_surprise.fit(full_data)
svd.fit(full_data)

# %%
user_ids = collaborative_df_explicit['user_id'].unique()

user_ids
# Out:
# array([     8,     99,    183, ..., 278637, 278843, 278851], dtype=int64)

# %%
recommandation_collaborative_top_k(5, 8, svd, collaborative_df_explicit, books)
# Out:
#          ISBN                                              title  \
# 0  0142001740                            The Secret Life of Bees
# 1  193156146X                           The Time Traveler's Wife
# 2  0743454529       My Sister's Keeper : A Novel (Picoult, Jodi)
# 3  0836213319                       Dilbert: A Book of Postcards
# 4  0439425220  Harry Potter and the Chamber of Secrets Postca...
#
#                author  year                publisher
# 0       Sue Monk Kidd  2003            Penguin Books
# 1  Audrey Niffenegger  2003  MacAdam/Cage Publishing
# 2        Jodi Picoult  2004                    Atria
# 3         Scott Adams  1996       Andrews McMeel Pub
# 4       J. K. Rowling  2002               Scholastic

# %%
recommandation_collaborative_top_k(5, 8, nmf_surprise, collaborative_df_explicit, books)
# Out:
#          ISBN                                              title  \
# 0  843760494X                              Cien AÃ±os de Soledad
# 1  3404701704                          Die Regeln des GlÃ?Â¼cks.
# 2  0380701006               Inside-Outside Book of New York City
# 3  0373196148  Caught By Surprise  (The Tale Of The Sea) (Sil...
# 4  1559210354  Imperial Woman (Buck, Pearl S. Oriental Novels...
#
#                      author  year               publisher
# 0  Gabriel GarcÃ­a MÃ¡rquez  1994  Ediciones Catedra S.A.
# 1                Dalai Lama  2001                LÃ?Â¼bbe
# 2               Herman Wouk  1986              Avon Books
# 3               Sandra Paul  2002              Silhouette
# 4             Pearl S. Buck  1991         Moyer Bell Ltd.

# %% [markdown]
# On obtient donc des recommandations totalement différentes. Comme SVD a le meilleur RMSE, on va choisir ce type de modèle pour la recommandation collaborative.

# %% [markdown]
# ## Utilisation de ALS pour la recommandation collaborative implicite

# %%
collaborative_df_implicit = pd.read_pickle('../../datasets/reco_datasets/ratings_implicit.pkl')

# %%
collaborative_df_implicit.reset_index(drop=True, inplace=True)
collaborative_df_implicit
# Out:
#         user_id        ISBN  rating
# 0        276725  034545104X       0
# 1        276727  0446520802       0
# 2        276733  2080674722       0
# 3        276746  0425115801       0
# 4        276746  0449006522       0
# ...         ...         ...     ...
# 716104   276704  059032120X       0
# 716105   276704  0679752714       0
# 716106   276704  080410526X       0
# 716107   276704  0876044011       0
# 716108   276706  0679447156       0
#
# [716109 rows x 3 columns]

# %%
collaborative_df_implicit['interaction'] = collaborative_df_implicit['rating'].apply(lambda x: 1 if x == 0 else x)

# %%
collaborative_df_implicit.head()
# Out:
#    user_id        ISBN  rating  interaction
# 0   276725  034545104X       0            1
# 1   276727  0446520802       0            1
# 2   276733  2080674722       0            1
# 3   276746  0425115801       0            1
# 4   276746  0449006522       0            1

# %%
import pandas as pd
import scipy.sparse as sp

def build_user_item_matrix_implicit(ratings: pd.DataFrame):
    """
    Construit une matrice user-item pour ALS implicite à partir d'un DataFrame
    avec colonnes ['user_id', 'ISBN', 'rating'].
    
    Les ratings == 0 sont considérés comme interactions implicites et
    transformés en valeur 1. Les ratings > 0 conservent leur poids.
    """
    # Transformer les ratings en interactions implicites
    ratings['interaction'] = ratings['rating'].apply(lambda x: 1 if x == 0 else x)

    # Encodage des IDs utilisateurs et livres en indices numériques continus
    user_ids = ratings["user_id"].astype("category")
    book_ids = ratings["ISBN"].astype("category")

    ratings["user_idx"] = user_ids.cat.codes
    ratings["book_idx"] = book_ids.cat.codes

    # Construire la matrice utilisateur-item sparse
    user_item_matrix = sp.csr_matrix(
        (ratings["interaction"], (ratings["user_idx"], ratings["book_idx"]))
    )

    # Mappings pour retrouver les vrais IDs ensuite
    user_mapping = dict(enumerate(user_ids.cat.categories))
    book_mapping = dict(enumerate(book_ids.cat.categories))

    return user_item_matrix, user_mapping, book_mapping

# %%
collaborative_df_implicit.sort_values('user_id', inplace=True)

# %%
from implicit.als import AlternatingLeastSquares

# Construire la matrice
user_item_matrix, user_mapping, book_mapping = build_user_item_matrix_implicit(collaborative_df_implicit)

# Entraîner ALS
als = AlternatingLeastSquares(
    factors=50,
    regularization=0.01,
    iterations=20,
    random_state=42
)

als.fit(user_item_matrix.T)  # important: items x users
# Out:
# c:\Users\redou\AppData\Local\Programs\Python\Python310\lib\site-packages\implicit\utils.py:164: ParameterWarning: Method expects CSR input, and was passed csc_matrix instead. Converting to CSR took 0.0070095062255859375 seconds
#   warnings.warn(
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
# Recommandations pour un utilisateur
user_idx = 0
recommended_items, scores = als.recommend(
    user_idx,
    user_item_matrix[user_idx],
    N=5
)

# Affichage avec mapping ISBN
for book_idx, score in zip(recommended_items, scores):
    print(book_mapping[book_idx], score)
# Out:
# 0330360434 0.0010230065
# 0060191414 0.0007004945
# 0205288626 0.00060519046
# 0020442106 0.0006031282
# 0310442508 0.00058559637

# %% [markdown]
# # Recommandation hybride
#
# On a deux manières différentes de faire des recommandations. On veut maintenant les combiner pour pouvoir recommander les livres les plus pertinents à l'utilisateur. Pour ça, on va calculer un score combinant à la fois la similarité cosinus et la prediction de note. Un poids alpha sera utilisé pour pouvoir gérer l'influence des types de recommandations.

# %%
# chargment des modèles

# basé sur le contenu

w2v=gensim.models.Word2Vec.load("./models/word2vec_model_text_fusion.model")
sbert=SentenceTransformer('./models/sbert_gpu/')

# collaboratif

_, svd= dump.load('./models/svd/svd_model_best')

# %%
# chargement des datasets

content_df=pd.read_pickle('./datasets/reco_datasets/content_dataset_sans_doublon_full.pkl')
collaborative_df_explicit = pd.read_csv('./datasets/reco_datasets/collaborative_dataset_explicit.csv')

# %%
content_df.drop(columns=['title_clean', 'description_clean', 'sujets_clean', 'author_clean', 'publisher_clean'], inplace=True)

# %%
# pour la recherche des titres

titles_clean=content_df['title'].apply(nettoyage_leger)

tfidf=TfidfVectorizer(ngram_range=(1, 5), lowercase=True, stop_words='english')

title_matrix=tfidf.fit_transform(titles_clean)


def search(title):
    title = nettoyage_leger(title)
    vec = tfidf.transform([title])
    similarite = cosine_similarity(vec, title_matrix).flatten()
    indice = np.argmax(similarite)
    res=content_df.iloc[indice]['title']
    return res
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 7
#       3 titles_clean=content_df['title'].apply(nettoyage_leger)
#       5 tfidf=TfidfVectorizer(ngram_range=(1, 5), lowercase=True, stop_words='english')
# ----> 7 title_matrix=tfidf.fit_transform(titles_clean)
#      10 def search(title):
#      11     title = nettoyage_leger(title)
#
# File c:\Users\redou\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_extraction\text.py:2104, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    2097 self._check_params()
#    2098 self._tfidf = TfidfTransformer(
#    2099     norm=self.norm,
#    2100     use_idf=self.use_idf,
#    2101     smooth_idf=self.smooth_idf,
#    2102     sublinear_tf=self.sublinear_tf,
#    2103 )
# -> 2104 X = super().fit_transform(raw_documents)
#    2105 self._tfidf.fit(X)
#    2106 # X is already a transformed view of raw_documents so
#    2107 # we set copy to False
#
# File c:\Users\redou\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\redou\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_extraction\text.py:1376, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1368             warnings.warn(
#    1369                 "Upper case characters found in"
#    1370                 " vocabulary while 'lowercase'"
#    1371                 " is True. These entries will not"
#    1372                 " be matched with any documents"
#    1373             )
#    1374             break
# -> 1376 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1378 if self.binary:
#    1379     X.data.fill(1)
#
# File c:\Users\redou\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_extraction\text.py:1276, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1274     j_indices.extend(feature_counter.keys())
#    1275     values.extend(feature_counter.values())
# -> 1276     indptr.append(len(j_indices))
#    1278 if not fixed_vocab:
#    1279     # disable defaultdict behaviour
#    1280     vocabulary = dict(vocabulary)
#
# KeyboardInterrupt:

# %%
# chargement des embeddings

with open('./datasets/embeddings_w2v.pkl', 'rb') as f:
    embedding_w2v = pickle.load(f)

with open('./datasets/embeddings.pkl', 'rb') as f:
    embeddings_bert = pickle.load(f)

# %%
content_df.head()
# Out:
#          ISBN                                              title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 3  0393045218                             The Mummies of Urumchi
# 4  0425176428  What If?: The World's Foremost Military Histor...
#
#                  author  year                 publisher  \
# 0    Mark P. O. Morford  2002   Oxford University Press
# 1  Richard Bruce Wright  2001     HarperFlamingo Canada
# 2      Gina Bari Kolata  1999      Farrar Straus Giroux
# 3       E. J. W. Barber  1999    W. W. Norton & Company
# 4         Robert Cowley  2000  Berkley Publishing Group
#
#                                               sujets  \
# 0                             [classical, mythology]
# 1  [sisters, actresses, young, new, ontario, teac...
# 2                [20th, history, century, influenza]
# 3  [xinjiang, mummies, age, uygur, china, prehist...
# 4              [histories, battles, wars, imaginary]
#
#                                          description
# 0  An excellent primer on classical mythology for...
# 1  E-book extras: "Hero of the Humdrum": A profil...
# 2  The fascinating, true story of the world's dea...
# 3  In the museums of Urumchi, the wind-swept regi...
# 4  With its in-depth reflections on the monumenta...

# %%
collaborative_df_explicit.head()
# Out:
#    user_id        ISBN  rating
# 0        8  0002005018       5
# 1       99  0312252617       8
# 2       99  0312261594       8
# 3       99  0316748641       7
# 4       99  0446677450      10

# %%
ids=sorted(set(collaborative_df_explicit['user_id']))
ids
# Out:
# [8,
#  99,
#  114,
#  183,
#  242,
#  243,
#  244,
#  254,
#  300,
#  383,
#  388,
#  424,
#  446,
#  487,
#  503,
#  505,
#  507,
#  566,
#  595,
#  625,
#  626,
#  638,
#  643,
#  651,
#  709,
#  735,
#  741,
#  753,
#  776,
#  805,
#  834,
#  850,
#  882,
#  900,
#  901,
#  929,
#  1025,
#  1063,
#  1075,
#  1083,
#  1116,
#  1129,
#  1131,
#  1155,
#  1167,
#  1211,
#  1248,
#  1343,
#  1409,
#  1412,
#  1424,
#  1435,
#  1548,
#  1558,
#  1585,
#  1660,
#  1674,
#  1706,
#  1725,
#  1733,
#  1790,
#  1805,
#  1848,
#  1850,
#  1903,
#  1928,
#  2010,
#  2012,
#  2024,
#  2030,
#  2033,
#  2041,
#  2084,
#  2103,
#  2110,
#  2132,
#  2134,
#  2139,
#  2179,
#  2189,
#  2197,
#  2276,
#  2287,
#  2288,
#  2313,
#  2337,
#  2358,
#  2363,
#  2399,
#  2406,
#  2411,
#  2437,
#  2439,
#  2442,
#  2462,
#  2549,
#  2589,
#  2622,
#  2685,
#  2719,
#  2766,
#  2769,
#  2789,
#  2793,
#  2799,
#  2891,
#  2954,
#  2977,
#  3017,
#  3145,
#  3167,
#  3192,
#  3282,
#  3326,
#  3329,
#  3331,
#  3346,
#  3363,
#  3371,
#  3373,
#  3416,
#  3418,
#  3462,
#  3471,
#  3538,
#  3556,
#  3569,
#  3578,
#  3594,
#  3640,
#  3669,
#  3675,
#  3693,
#  3719,
#  3757,
#  3814,
#  3817,
#  3827,
#  3840,
#  3917,
#  3923,
#  3965,
#  3983,
#  4017,
#  4091,
#  4092,
#  4098,
#  4114,
#  4131,
#  4149,
#  4157,
#  4197,
#  4221,
#  4223,
#  4334,
#  4365,
#  4385,
#  4420,
#  4435,
#  4483,
#  4514,
#  4570,
#  4571,
#  4600,
#  4622,
#  4769,
#  4785,
#  4795,
#  4802,
#  4809,
#  4816,
#  4838,
#  4896,
#  4938,
#  5037,
#  5048,
#  5127,
#  5163,
#  5204,
#  5207,
#  5209,
#  5225,
#  5286,
#  5331,
#  5333,
#  5350,
#  5385,
#  5416,
#  5439,
#  5448,
#  5476,
#  5490,
#  5499,
#  5539,
#  5543,
#  5555,
#  5582,
#  5609,
#  5638,
#  5665,
#  5709,
#  5722,
#  5728,
#  5741,
#  5777,
#  5815,
#  5834,
#  5899,
#  5903,
#  5920,
#  5932,
#  5956,
#  5963,
#  5998,
#  6073,
#  6092,
#  6115,
#  6238,
#  6242,
#  6249,
#  6251,
#  6273,
#  6280,
#  6323,
#  6330,
#  6333,
#  6345,
#  6366,
#  6398,
#  6431,
#  6497,
#  6505,
#  6509,
#  6532,
#  6537,
#  6543,
#  6563,
#  6564,
#  6566,
#  6575,
#  6577,
#  6604,
#  6611,
#  6662,
#  6671,
#  6679,
#  6689,
#  6731,
#  6769,
#  6772,
#  6781,
#  6789,
#  6840,
#  6865,
#  6871,
#  6889,
#  6894,
#  6958,
#  7056,
#  7060,
#  7072,
#  7079,
#  7082,
#  7105,
#  7125,
#  7128,
#  7134,
#  7155,
#  7158,
#  7181,
#  7210,
#  7283,
#  7286,
#  7312,
#  7346,
#  7352,
#  7371,
#  7418,
#  7426,
#  7528,
#  7547,
#  7565,
#  7569,
#  7620,
#  7809,
#  7841,
#  7860,
#  7864,
#  7882,
#  7887,
#  7890,
#  7913,
#  7915,
#  7930,
#  7958,
#  7970,
#  7980,
#  8019,
#  8040,
#  8066,
#  8067,
#  8094,
#  8095,
#  8167,
#  8187,
#  8188,
#  8201,
#  8234,
#  8245,
#  8250,
#  8253,
#  8255,
#  8284,
#  8290,
#  8314,
#  8323,
#  8344,
#  8362,
#  8454,
#  8487,
#  8529,
#  8570,
#  8584,
#  8590,
#  8660,
#  8680,
#  8681,
#  8687,
#  8695,
#  8734,
#  8737,
#  8765,
#  8782,
#  8801,
#  8844,
#  8864,
#  8870,
#  8872,
#  8890,
#  8935,
#  8936,
#  8937,
#  8971,
#  9029,
#  9094,
#  9138,
#  9139,
#  9143,
#  9177,
#  9183,
#  9188,
#  9224,
#  9226,
#  9227,
#  9276,
#  9313,
#  9344,
#  9354,
#  9357,
#  9381,
#  9408,
#  9414,
#  9417,
#  9440,
#  9454,
#  9504,
#  9568,
#  9571,
#  9574,
#  9613,
#  9660,
#  9717,
#  9747,
#  9806,
#  9850,
#  9856,
#  9908,
#  9974,
#  10030,
#  10067,
#  10118,
#  10199,
#  10241,
#  10314,
#  10315,
#  10354,
#  10447,
#  10532,
#  10560,
#  10570,
#  10590,
#  10619,
#  10660,
#  10668,
#  10681,
#  10699,
#  10750,
#  10819,
#  10836,
#  10875,
#  10917,
#  10927,
#  10946,
#  10949,
#  10965,
#  10985,
#  11070,
#  11120,
#  11179,
#  11198,
#  11201,
#  11224,
#  11231,
#  11245,
#  11279,
#  11325,
#  11362,
#  11393,
#  11399,
#  11400,
#  11451,
#  11456,
#  11464,
#  11517,
#  11521,
#  11529,
#  11532,
#  11590,
#  11601,
#  11621,
#  11629,
#  11638,
#  11657,
#  11676,
#  11687,
#  11690,
#  11708,
#  11718,
#  11724,
#  11776,
#  11788,
#  11805,
#  11817,
#  11832,
#  11916,
#  11924,
#  11944,
#  11974,
#  11993,
#  12081,
#  12100,
#  12112,
#  12122,
#  12123,
#  12137,
#  12143,
#  12154,
#  12194,
#  12209,
#  12246,
#  12272,
#  12282,
#  12331,
#  12348,
#  12362,
#  12515,
#  12537,
#  12538,
#  12569,
#  12576,
#  12619,
#  12650,
#  12657,
#  12698,
#  12702,
#  12707,
#  12734,
#  12756,
#  12780,
#  12784,
#  12811,
#  12824,
#  12835,
#  12863,
#  12917,
#  12945,
#  12951,
#  12981,
#  12982,
#  12990,
#  13032,
#  13060,
#  13080,
#  13082,
#  13093,
#  13094,
#  13126,
#  13164,
#  13173,
#  13221,
#  13223,
#  13268,
#  13273,
#  13279,
#  13280,
#  13331,
#  13347,
#  13491,
#  13518,
#  13551,
#  13552,
#  13582,
#  13600,
#  13604,
#  13607,
#  13664,
#  13666,
#  13668,
#  13682,
#  13709,
#  13716,
#  13733,
#  13850,
#  13867,
#  13896,
#  13935,
#  13973,
#  13995,
#  14007,
#  14049,
#  14079,
#  14087,
#  14164,
#  14173,
#  14180,
#  14232,
#  14271,
#  14281,
#  14336,
#  14374,
#  14387,
#  14392,
#  14393,
#  14422,
#  14449,
#  14451,
#  14456,
#  14461,
#  14517,
#  14521,
#  14541,
#  14573,
#  14638,
#  14643,
#  14667,
#  14672,
#  14683,
#  14698,
#  14744,
#  14768,
#  14808,
#  14897,
#  14945,
#  14958,
#  14998,
#  15021,
#  15040,
#  15046,
#  15049,
#  15076,
#  15093,
#  15135,
#  15144,
#  15150,
#  15185,
#  15208,
#  15230,
#  15371,
#  15408,
#  15418,
#  15497,
#  15500,
#  15542,
#  15589,
#  15602,
#  15651,
#  15654,
#  15670,
#  15819,
#  15834,
#  15845,
#  15918,
#  15922,
#  15936,
#  15945,
#  15957,
#  15962,
#  15964,
#  16005,
#  16009,
#  16010,
#  16036,
#  16046,
#  16086,
#  16106,
#  16110,
#  16121,
#  16155,
#  16161,
#  16220,
#  16231,
#  16237,
#  16244,
#  16246,
#  16258,
#  16263,
#  16319,
#  16383,
#  16417,
#  16488,
#  16504,
#  16510,
#  16545,
#  16551,
#  16585,
#  16599,
#  16601,
#  16634,
#  16654,
#  16666,
#  16684,
#  16708,
#  16713,
#  16717,
#  16718,
#  16721,
#  16730,
#  16749,
#  16755,
#  16777,
#  16781,
#  16795,
#  16818,
#  16835,
#  16867,
#  16871,
#  16876,
#  16877,
#  16908,
#  16916,
#  16919,
#  16935,
#  16943,
#  16949,
#  16966,
#  16982,
#  16996,
#  16999,
#  17003,
#  17045,
#  17046,
#  17054,
#  17065,
#  17068,
#  17172,
#  17177,
#  17180,
#  17183,
#  17190,
#  17224,
#  17233,
#  17282,
#  17330,
#  17353,
#  17391,
#  17402,
#  17493,
#  17507,
#  17578,
#  17596,
#  17667,
#  17724,
#  17761,
#  17763,
#  17766,
#  17789,
#  17859,
#  17894,
#  17906,
#  17926,
#  17950,
#  17970,
#  18016,
#  18038,
#  18067,
#  18082,
#  18095,
#  18096,
#  18132,
#  18134,
#  18155,
#  18166,
#  18167,
#  18170,
#  18172,
#  18176,
#  18203,
#  18254,
#  18294,
#  18309,
#  18311,
#  18323,
#  18366,
#  18384,
#  18385,
#  18395,
#  18398,
#  18401,
#  18412,
#  18429,
#  18439,
#  18464,
#  18519,
#  18671,
#  18710,
#  18714,
#  18722,
#  18850,
#  18852,
#  18886,
#  18922,
#  18945,
#  18963,
#  18979,
#  19011,
#  19018,
#  19019,
#  19085,
#  19145,
#  19206,
#  19220,
#  19233,
#  19303,
#  19336,
#  19362,
#  19422,
#  19429,
#  19493,
#  19503,
#  19570,
#  19571,
#  19573,
#  19605,
#  19611,
#  19664,
#  19681,
#  19711,
#  19725,
#  19760,
#  19815,
#  19842,
#  19866,
#  19885,
#  19935,
#  19969,
#  19970,
#  19972,
#  19974,
#  19983,
#  20005,
#  20022,
#  20032,
#  20034,
#  20060,
#  20062,
#  20106,
#  20115,
#  20119,
#  20147,
#  20149,
#  20150,
#  20172,
#  20180,
#  20201,
#  20245,
#  20250,
#  20254,
#  20265,
#  20294,
#  20332,
#  20336,
#  20345,
#  20347,
#  20350,
#  20388,
#  20401,
#  20409,
#  20418,
#  20448,
#  20462,
#  20484,
#  20501,
#  20561,
#  20622,
#  20627,
#  20629,
#  20668,
#  20680,
#  20703,
#  20755,
#  20794,
#  20801,
#  20804,
#  20806,
#  20857,
#  20871,
#  20916,
#  20918,
#  20961,
#  20971,
#  21011,
#  21014,
#  21031,
#  21049,
#  21112,
#  21116,
#  21155,
#  21202,
#  21207,
#  21229,
#  21252,
#  21356,
#  21357,
#  21364,
#  21368,
#  21370,
#  21404,
#  21406,
#  21462,
#  21469,
#  21484,
#  21490,
#  21540,
#  21575,
#  21576,
#  21593,
#  21618,
#  21659,
#  21684,
#  21708,
#  21750,
#  21774,
#  21860,
#  21875,
#  21895,
#  21903,
#  21912,
#  21918,
#  21930,
#  21937,
#  22012,
#  22015,
#  22022,
#  22023,
#  22045,
#  22062,
#  22074,
#  22089,
#  22107,
#  22126,
#  22154,
#  22167,
#  22200,
#  22252,
#  22296,
#  22338,
#  22362,
#  22365,
#  22409,
#  22461,
#  22464,
#  22495,
#  22503,
#  22521,
#  22532,
#  22547,
#  22617,
#  22624,
#  22625,
#  22637,
#  22657,
#  22695,
#  22710,
#  22747,
#  22773,
#  22780,
#  22813,
#  22818,
#  22824,
#  22830,
#  22851,
#  22885,
#  22888,
#  22912,
#  22922,
#  22936,
#  22964,
#  22975,
#  22981,
#  23020,
#  23065,
#  23070,
#  23124,
#  23127,
#  23128,
#  23138,
#  23200,
#  23204,
#  23231,
#  23271,
#  23288,
#  23392,
#  23408,
#  23450,
#  23459,
#  23498,
#  23511,
#  23547,
#  23571,
#  23582,
#  23619,
#  23624,
#  23631,
#  23642,
#  23650,
#  23652,
#  23659,
#  23680,
#  23699,
#  23768,
#  23771,
#  23835,
#  23847,
#  23871,
#  23872,
#  23881,
#  23902,
#  23933,
#  23939,
#  24027,
#  24052,
#  24082,
#  24090,
#  24105,
#  24172,
#  24186,
#  24188,
#  24191,
#  24193,
#  24194,
#  24204,
#  24217,
#  24342,
#  24348,
#  24379,
#  24391,
#  24427,
#  24433,
#  24440,
#  24452,
#  24458,
#  24459,
#  24462,
#  24515,
#  24525,
#  24556,
#  24570,
#  24585,
#  24612,
#  24624,
#  24627,
#  24641,
#  24694,
#  24697,
#  24733,
#  24767,
#  24768,
#  24769,
#  24773,
#  24778,
#  24835,
#  24838,
#  24846,
#  24878,
#  24921,
#  24922,
#  24933,
#  24934,
#  24945,
#  24960,
#  ...]

# %%
# Version basée uniquement sur les livres du dataset

def calcul_score_content(book_title, embeddings, books, n=5):

    close_title=search(book_title)
    print(close_title)
    book_index=np.where(close_title==books['title'])[0][0]

    similarity = cosine_similarity([embeddings[book_index]], embeddings)[0]
    similarity[book_index] = -1

    id_recos = np.argsort(similarity)[-n:][::-1] 
    scores = similarity[id_recos]

    return scores, id_recos

# %% [markdown]
# L'utilisateur pourra créer son profile avec les livres qu'il aime même s'ils ne sont pas dans le dataset. Les fonctions d'après servent à faire des recommandations basées sur le contenu même de livres non présents dans le dataset.

# %%
def get_vector(text, model):
    """Calcule l'embedding moyen d'un texte avec un modèle Word2Vec."""
    words = text.lower().split()
    word_vecs = [model.wv[w] for w in words if w in model.wv]
    return np.mean(word_vecs, axis=0) if word_vecs else np.zeros(model.vector_size)

def calcul_score_content(book_title, embeddings, model, n=5):
    """
    Calcule les similarités entre un livre donné et la base `books` via Word2Vec.
    book_title : str -> titre du livre à comparer (même s'il n'est pas dans books)
    embeddings : np.array -> embeddings pré-calculés pour books
    books : DataFrame avec au moins une colonne 'title'
    model : Word2Vec entraîné sur le même espace
    n : nombre de recommandations à retourner
    """
    
    # Embedding du livre donné
    query_vec = get_vector(book_title, model)

    # Calcul des similarités
    similarity = cosine_similarity([query_vec], embeddings)[0]

    # Top n indices
    id_recos = np.argsort(similarity)[-n:][::-1] 
    scores = similarity[id_recos]

    return scores, id_recos

# %%
# Recommandations basées sur SBERT
def calcul_score_content_sbert(book_title, books, embeddings, model, n=5):
    # Encode le livre recherché
    book_embedding = model.encode([book_title], convert_to_numpy=True, normalize_embeddings=True)
    
    # Similarité cosinus avec tous les livres
    similarity = cosine_similarity(book_embedding, embeddings)[0]
    
    # Exclure le livre lui-même s'il est dans le dataset
    match_idx = books.index[books['title'] == book_title]
    if len(match_idx) > 0:
        similarity[match_idx[0]] = -1
    
    # Top-n recommandations
    id_recos = np.argsort(similarity)[-n:][::-1]
    scores = similarity[id_recos]
    
    return scores, id_recos

# %%
scores, id_recos = calcul_score_content('Harry Potter', embedding_w2v, w2v)
content_df.iloc[id_recos]
# Out:
#              ISBN                                             title  \
# 52942  0439193966  Horrible Harry Goes to the Moon (Horrible Harry)
# 1329   0439064872  Harry Potter and the Chamber of Secrets (Book 2)
# 33591  0590466372          Horrible Harry's Secret (Horrible Harry)
# 34401  0689714769                    Harry Houdini : Young Magician
# 25460  0590424025                    Harry Houdini: Master of Magic
#
#                       author  year        publisher  \
# 52942             Suzy Kline  2001  Scholastic Inc.
# 1329           J. K. Rowling  2000       Scholastic
# 33591             Suzy Kline  1993  Scholastic Inc.
# 34401  Kathryn Kilby Borland  1991          Aladdin
# 25460          Robert Kraske  1995       Scholastic
#
#                                                   sujets  \
# 52942  [juvenile, fictitious, schools, harry, fiction...
# 1329   [juvenile, fictitious, wizards, schools, magic...
# 33591                     [fiction, friendship, schools]
# 34401  [literature, juvenile, artists, escape, 1926, ...
# 25460  [arts, books, children, juvenile, nonfiction, ...
#
#                                              description
# 52942  Inspired by his third-grade class's study of t...
# 1329   Throughout the summer holidays after his first...
# 33591  Horrible Harry falls in love with Song Lee, an...
# 34401  A biography of Harry Houdini concentrating on ...
# 25460  A brief biography of Ehrich Weiss, who gained ...

# %%
scores, id_recos = calcul_score_content_sbert('Harry Potter', content_df, embeddings_bert, sbert)
content_df.iloc[id_recos]
# Out:
#              ISBN                                              title  \
# 25239  0312282540  Harry Potter, You're the Best: A Tribute from ...
# 12291  0415933749  Harry Potter's World: Multidisciplinary Critic...
# 353    0767908473  The Sorcerer's Companion: A Guide to the Magic...
# 7225   0439286239  Harry Potter and the Sorcerer's Stone Movie Po...
# 46041  0803718314             The Bell, the Book and the Spellbinder
#
#                      author  year           publisher  \
# 25239          Sharon Moore  2001  St. Martin's Press
# 12291  Elizabeth E. Heilman  2003        Falmer Press
# 353      ALLAN ZOLA KRONZEK  2001            Broadway
# 7225   Inc Staff Scholastic  2001          Scholastic
# 46041       Brad Strickland  1997          Dial Books
#
#                                                   sujets  \
# 25239  [books, contemporary, children, juvenile, crit...
# 12291  [books, children, criticism, magic, character,...
# 353    [manuals, children, criticism, etc, magic, cha...
# 7225                            [book, pictures, poster]
# 46041                          [magic, wizards, fiction]
#
#                                              description
# 25239                          this book sucks dont read
# 12291  The Harry Potter books have become ubiquitous ...
# 353    Who was the real Nicholas Flamel? How did the ...
# 7225   Harry Potter fans of all ages will treasure th...
# 46041  Johnny Dixon's best friend Fergie steals an en...

# %%
recommandation_collaborative_top_k(5, ids[0], svd, collaborative_df_explicit, books, ids)
# Out:
#        user_id        ISBN  note_predite  \
# 9881         8  0439425220      9.126137
# 5068         8  0743454529      9.114931
# 14143        8  0836213319      8.984506
# 17854        8  067168390X      8.915766
# 9203         8  0836220889      8.896413
#
#                                                    title
# 9881   Harry Potter and the Chamber of Secrets Postca...
# 5068        My Sister's Keeper : A Novel (Picoult, Jodi)
# 14143                       Dilbert: A Book of Postcards
# 17854                                      Lonesome Dove
# 9203                                   Calvin and Hobbes

# %%
def recommandation_hybride(user_id, collaborative_model, content_df, collaborative_df, books, embeddings, ids, alpha=0.5, n=5):

    recos_collab = recommandation_collaborative_top_k(n, user_id, collaborative_model, collaborative_df, books, ids)
    if recos_collab is None:
        return
    
    print(recos_collab)
 
    score_collab = np.array(recos_collab['note_predite'].tolist())
    isbn_collab = recos_collab['ISBN'].to_list()

    score_content_global = np.zeros(len(content_df))

    for isbn, s_collab in tqdm(zip(isbn_collab, score_collab), total=len(isbn_collab)):
        print(isbn, s_collab)
        
        ref_index = np.where(isbn == content_df['ISBN'])[0]
        if len(ref_index) == 0:
            continue
        ref_index = ref_index[0]

        sim = cosine_similarity([embeddings[ref_index]], embeddings)[0]
        sim[ref_index] = 0

        score_content_global += sim * s_collab

    score_content_norm = (score_content_global - score_content_global.min()) / (score_content_global.max() - score_content_global.min() + 1e-8)

    score_collab_global = np.zeros(len(content_df))
    for title, s_collab in zip(isbn_collab, score_collab):
        idx = np.where(isbn == content_df['ISBN'])[0]
        if len(idx) > 0:
            score_collab_global[idx[0]] = s_collab

    score_collab_norm = (score_collab_global - score_collab_global.min()) / (score_collab_global.max() - score_collab_global.min() + 1e-8)

    score_final = alpha * score_collab_norm + (1 - alpha) * score_content_norm

    result_df = content_df.copy()
    result_df['score_hybride'] = score_final

    livres_lus = set(isbn_collab)
    result_df = result_df[~result_df['title'].isin(livres_lus)]
    result_df = result_df.sort_values('score_hybride', ascending=False)

    return result_df.head(n)

# %%
user_id=ids[0]

# %%
recos=recommandation_hybride(user_id, svd, content_df, collaborative_df_explicit, books, embeddings_bert, ids)
print(f"Recommandation pour l'utilisateur n°{user_id} :\n")

recos
# Out:
#        user_id        ISBN  note_predite  \
# 9881         8  0439425220      9.126137
# 5068         8  0743454529      9.114931
# 14143        8  0836213319      8.984506
# 17854        8  067168390X      8.915766
# 9203         8  0836220889      8.896413
#
#                                                    title
# 9881   Harry Potter and the Chamber of Secrets Postca...
# 5068        My Sister's Keeper : A Novel (Picoult, Jodi)
# 14143                       Dilbert: A Book of Postcards
# 17854                                      Lonesome Dove
# 9203                                   Calvin and Hobbes
#  40%|████      | 2/5 [00:00<00:00, 10.63it/s]
# 0439425220 9.12613716850456
# 0743454529 9.114930743799865
# 100%|██████████| 5/5 [00:00<00:00, 23.10it/s]
# 0836213319 8.984506384093908
# 067168390X 8.915766497102478
# 0836220889 8.896412602406246
# Recommandation pour l'utilisateur n°8 :
#              ISBN                                 title              author  \
# 3378   0553280074          Goodbye Doesn't Mean Forever    LURLENE MCDANIEL
# 23640  0451207009               The Language of Sisters            Amy Yurk
# 14518  0553562657  A Season for Goodbye (One Last Wish)    LURLENE MCDANIEL
# 29925  0440147433                         Little Sister  Patricia MacDonald
# 10325  0671776126                           Plain Truth        Jodi Picoult
#
#        year                publisher  \
# 3378   1989                   Bantam
# 23640  2002     New American Library
# 14518  1995              Laurel Leaf
# 29925  1986  Dell Publishing Company
# 10325  2000                    Atria
#
#                                                   sujets  \
# 3378               [leukemia, teenagers, death, fiction]
# 23640  [sisters, victims, disabilities, people, young...
# 14518  [books, camps, children, teenagers, juvenile, ...
# 29925                                                 []
# 10325  [mystery, detective, legal, infanticide, trial...
#
#                                              description  score_hybride
# 3378   Jory Delaney has always had lots of money. But...       0.500000
# 23640  "Ten years ago, Nicole Hunter left her trouble...       0.490701
# 14518  It's been a year since Katie O'Roark, Chelsea ...       0.484193
# 29925  Beth Pearson has never much liked her younger ...       0.482792
# 10325  From the bestselling author of My Sister's Kee...       0.481316
